# %% [markdown]
# ## Code preamble Import packages

# %%
import pandas as pd
import numpy as np
import json
import requests
import altair as alt
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Writing figure tex

# %%
def format_strings(test_str):
    test_str = test_str.replace("_","")
    for ele in test_str:
        if ele.isdigit():
            test_str = test_str.replace(ele,  num_to_word(ele))
    return test_str
def num_to_word(num):
    n_dict = {0:'zero', 1:'one', 2:'two', 3:'three', 4:'four', 5:'five', 6:'six', 
              7:'seven',8:'eight', 9:'nine', 10:'ten', 11:'eleven', 12:'twelve',
              13:'thirteen', 14:'fourteen', 15: 'fifteen'}
    return n_dict[int(num)].title()

# %%
def pathway_figure_tex(label, fname, score, filter):
    list_str= [label, fname]
    method, fname = [format_strings(i_str) for i_str in list_str]
    score_lab = score.title().replace(" ", "")
    filter_lab = filter.title().replace(" ", "")
    beg_str = "\n \\newcommand{\\figurePathway"+label+score_lab+filter_lab+"}{\\begin{subfigure}[t]{\doublefigurewidth} \n"
    mid_str = "\includegraphics[width=\linewidth] {"+fname+"} \n"
    cap_str = "\caption{Pathway enrichment for the clustering method: "+label+". \n Showing the "+filter+" based on the "+score+".\label{fig::"+label+score_lab+filter_lab+"}}"
    end_str = "\end{subfigure} \n} \n"
    return(beg_str+mid_str+cap_str+end_str)

# %% [markdown]
# ### Set the directories

# %%
path_dir_clone = "../../PheWAS-cluster-main/working-example/data"
path_dir = "../NealesLabData"
tex_dir = "../../../Documents/Reports/Clustering"
path_plots = "./Darrous_plots_all/"

# %% [markdown]
# ### Load the clusters

# %%
clustering_info = pd.read_csv(path_dir+"/cluster_labels.csv", index_col=0)
clustering_info.head()
cluster_method_labels = list(clustering_info.index)
cluster_method_labels.remove("SpectralProposed")
cluster_method_labels.remove("LloydRProposed")

# %%
clust_df = pd.read_csv(path_dir+"/ours_clusters.csv", index_col = 0)
clust_df.head()
# Out:
#              body_size      1697      1717  20015_irnt      2306  23101_irnt  \
# rs115866895  -1.384558  0.078427  0.064179    1.313715 -0.390765   -1.428121
# rs4648450    -1.280939  0.667544  0.025040    0.907814  0.041965   -2.116211
# rs12024554   -1.758457  1.511510  0.407248    4.120851  0.602471   -0.676939
# rs1097327    -1.027856 -0.284528 -0.186588    1.438508 -0.030276   -1.195410
# rs3737992    -0.226169 -1.735855  0.039532   -1.505157 -0.230216   -2.347974
#
#              23102_irnt  23105_irnt  23106_irnt  23107_irnt  ...  \
# rs115866895   -1.395080   -1.765438    2.115427    1.865250  ...
# rs4648450     -2.090042   -2.321914    2.290245    1.904075  ...
# rs12024554    -0.701834   -0.828185    2.797708    2.548867  ...
# rs1097327     -1.167861   -1.501871    1.218832    1.538645  ...
# rs3737992     -2.330429   -2.498627    1.603422    1.071926  ...
#
#              KmeansCosineMinibatchSixProposed  KmedoidsCosineSixProposed  \
# rs115866895                                 1                          3
# rs4648450                                   1                          3
# rs12024554                                  4                          3
# rs1097327                                   4                          3
# rs3737992                                   1                          1
#
#              GMMZeroProposed  GMMOneProposed  BirchZeroProposed  \
# rs115866895                1               4                227
# rs4648450                  1               1                252
# rs12024554                 0               0                253
# rs1097327                  0               0                300
# rs3737992                  1               4                195
#
#              BirchOneProposed  BirchTwoProposed  SpectralProposed  \
# rs115866895                 0                 0               NaN
# rs4648450                   0                 0               NaN
# rs12024554                  0                 0               NaN
# rs1097327                   0                 0               NaN
# rs3737992                   0                 0               NaN
#
#              KmeansCosineTwoMinAICProposed  KmedoidsCosineThreeMinAICProposed
# rs115866895                              1                                  1
# rs4648450                                1                                  1
# rs12024554                               1                                  1
# rs1097327                                1                                  1
# rs3737992                                1                                  1
#
# [5 rows x 433 columns]

# %% [markdown]
# ### Load the PCAs

# %%
pc_ours_df = pd.read_csv(path_dir+"/pcas_ours.csv", index_col=0)
pc_ours_with_exp_df = pd.read_csv(path_dir+"/pcas_ours_with_exp.csv", index_col=0)
pc_pap_df = pd.read_csv(path_dir+"/pcas_paper.csv", index_col=0)

# %% [markdown]
# ### Load the Genes-Snps
# The `Genes` have been found using the function `SNP2GENE` from [FUMA](https://fuma.ctglab.nl/). This requires the `GWAS` data to be uploaded with the following compulsary columns:
# * Either Chromosome and Position or rsid.
# * Effect Allele
# * Sample size.
# This must be input as a txt file with space separated data and `\n` separated rows.

# %%
genes_df = pd.read_csv(path_dir+'/genes.txt', sep="\t", header=0)
genes_df.head()
# Out:
#               ensg    symbol  chr    start      end  strand            type  \
# 0  ENSG00000197530      MIB2    1  1550795  1565990       1  protein_coding
# 1  ENSG00000189409    MMP23B    1  1567474  1570639       1  protein_coding
# 2  ENSG00000248333    CDK11B    1  1570603  1590473      -1  protein_coding
# 3  ENSG00000189339  SLC35E2B    1  1592939  1624167      -1  protein_coding
# 4  ENSG00000157873  TNFRSF14    1  2487078  2496821       1  protein_coding
#
#    entrezID      HUGO       pLI    ncRVIS  posMapSNPs  posMapMaxCADD  \
# 0  142678.0      MIB2  0.000159  0.030973           4          3.164
# 1    8510.0    MMP23B       NaN       NaN           5          3.164
# 2  728642.0    CDK11B  0.728294       NaN          34         11.560
# 3  728661.0  SLC35E2B  0.621002 -0.794611          34         11.560
# 4    8764.0  TNFRSF14  0.819999 -0.131268           1          1.637
#
#        minGwasP   IndSigSNPs GenomicLocus
# 0           NaN  rs115866895            1
# 1           NaN  rs115866895            1
# 2  1.617240e-15  rs115866895            1
# 3  1.617240e-15  rs115866895            1
# 4           NaN    rs4648450            2

# %%
gene_snps = genes_df[["symbol", "IndSigSNPs"]]
gene_snps.value_counts()
full_gene_list = np.unique(gene_snps["symbol"].values)

# %% [markdown]
# ### Construct the Clusters in terms of Genes

# %%
snp_clusters_df = clust_df[clust_df.columns[clust_df.columns.isin(cluster_method_labels)]]
cluster_method_labels = [lab for lab in cluster_method_labels if lab in clust_df.columns]
gene_clust_df = pd.DataFrame(columns = cluster_method_labels)
snp_clusters_df
# Out:
#              KmeansLloydStdFourProposed  KmeansLloydStdFourDarrous  \
# rs115866895                           1                          1
# rs4648450                             3                          2
# rs12024554                            1                          0
# rs1097327                             3                          3
# rs3737992                             1                          2
# ...                                 ...                        ...
# rs8134638                             0                          0
# rs2837398                             0                          0
# rs76040172                            3                          1
# rs6001870                             3                          2
# rs28489620                            3                          2
#
#              KmeansLloydStdSixProposed  KmeansLloydStdSixDarrous  \
# rs115866895                          2                         4
# rs4648450                            1                         0
# rs12024554                           2                         4
# rs1097327                            4                         3
# rs3737992                            1                         0
# ...                                ...                       ...
# rs8134638                            0                         4
# rs2837398                            0                         4
# rs76040172                           4                         5
# rs6001870                            1                         0
# rs28489620                           1                         2
#
#              KmeansElkanStdFourProposed  KmeansElkanStdFourDarrous  \
# rs115866895                           1                          1
# rs4648450                             3                          2
# rs12024554                            1                          0
# rs1097327                             3                          3
# rs3737992                             1                          2
# ...                                 ...                        ...
# rs8134638                             0                          0
# rs2837398                             0                          0
# rs76040172                            3                          1
# rs6001870                             3                          2
# rs28489620                            3                          2
#
#              KmedoidsEuclideanProposedFour  KmeansCosineSixProposed  \
# rs115866895                              0                        1
# rs4648450                                0                        1
# rs12024554                               0                        2
# rs1097327                                0                        3
# rs3737992                                3                        1
# ...                                    ...                      ...
# rs8134638                                2                        4
# rs2837398                                1                        4
# rs76040172                               0                        1
# rs6001870                                3                        3
# rs28489620                               0                        1
#
#              DBScanZeroProposed  DBScanOneProposed  DBScanTwoProposed  \
# rs115866895                   0                 -1                 -1
# rs4648450                    -1                 -1                 -1
# rs12024554                   -1                 -1                 -1
# rs1097327                    -1                 -1                 -1
# rs3737992                     0                 -1                 -1
# ...                         ...                ...                ...
# rs8134638                    -1                 -1                 -1
# rs2837398                    -1                 -1                 -1
# rs76040172                    0                 -1                 -1
# rs6001870                     0                 -1                 -1
# rs28489620                   -1                 -1                 -1
#
#              KmeansCosineMinibatchSixProposed  KmedoidsCosineSixProposed  \
# rs115866895                                 1                          3
# rs4648450                                   1                          3
# rs12024554                                  4                          3
# rs1097327                                   4                          3
# rs3737992                                   1                          1
# ...                                       ...                        ...
# rs8134638                                   2                          5
# rs2837398                                   2                          4
# rs76040172                                  1                          3
# rs6001870                                   4                          1
# rs28489620                                  4                          3
#
#              GMMZeroProposed  GMMOneProposed  BirchZeroProposed  \
# rs115866895                1               4                227
# rs4648450                  1               1                252
# rs12024554                 0               0                253
# rs1097327                  0               0                300
# rs3737992                  1               4                195
# ...                      ...             ...                ...
# rs8134638                  2               2                 43
# rs2837398                  2               2                160
# rs76040172                 1               4                251
# rs6001870                  0               3                323
# rs28489620                 1               1                194
#
#              BirchOneProposed  BirchTwoProposed  \
# rs115866895                 0                 0
# rs4648450                   0                 0
# rs12024554                  0                 0
# rs1097327                   0                 0
# rs3737992                   0                 0
# ...                       ...               ...
# rs8134638                   1                 1
# rs2837398                   1                 1
# rs76040172                  0                 0
# rs6001870                   0                 0
# rs28489620                  0                 0
#
#              KmeansCosineTwoMinAICProposed  KmedoidsCosineThreeMinAICProposed
# rs115866895                              1                                  1
# rs4648450                                1                                  1
# rs12024554                               1                                  1
# rs1097327                                1                                  1
# rs3737992                                1                                  1
# ...                                    ...                                ...
# rs8134638                                0                                  2
# rs2837398                                0                                  2
# rs76040172                               1                                  1
# rs6001870                                1                                  1
# rs28489620                               1                                  1
#
# [324 rows x 20 columns]

# %%
gene_clust_dict = {} #pd.DataFrame(index = genes_df.symbol.values)
for clust_lab in cluster_method_labels:
    # Get the clusters by snps for cluster method clust_lab
    clust_single = snp_clusters_df.loc[:, clust_lab]
    # Get the possible cluster numbers
    clust_nums = clust_single.unique()
    gene_clust_single_df = pd.DataFrame(
        columns = [clust_lab+"_"+str(c_n) for c_n in clust_nums]
    )
    for c_num in clust_nums:
        col_lab = clust_lab+"_"+str(c_num)
        # snps matching clusters
        clust_snps = list(clust_df[clust_single == c_num].index)
        # genes prevent in those snps
        genes = list(genes_df[genes_df["IndSigSNPs"].isin(clust_snps)].symbol.unique())
        # genes marked with 1 if in cluster 0 if not.
        gene_clust_c_num_df = pd.DataFrame(
            index = genes,
            data = {
                col_lab: 1
            }
        )
        extra_genes = list(np.setdiff1d(full_gene_list, genes))
        gene_clust_not_in_df = pd.DataFrame(
            index = extra_genes,
            data = {
                col_lab: 0
            }
        )
        gene_clust_c_num_df = pd.concat([gene_clust_c_num_df, gene_clust_not_in_df],
                                        axis = 0
        )
        gene_clust_single_df[col_lab] = gene_clust_c_num_df
    gene_clust_dict[clust_lab] = gene_clust_single_df

# %%
for lab in gene_clust_dict:
    gene_clust_dict[lab].to_csv(path_dir+"/gene_clusters_" + lab + ".csv",
                     header = True,
                     index= True,
                     sep = ",")
genes_df
# Out:
#                 ensg    symbol  chr     start       end  strand  \
# 0    ENSG00000197530      MIB2    1   1550795   1565990       1
# 1    ENSG00000189409    MMP23B    1   1567474   1570639       1
# 2    ENSG00000248333    CDK11B    1   1570603   1590473      -1
# 3    ENSG00000189339  SLC35E2B    1   1592939   1624167      -1
# 4    ENSG00000157873  TNFRSF14    1   2487078   2496821       1
# ..               ...       ...  ...       ...       ...     ...
# 592  ENSG00000196419     XRCC6   22  42017123  42060044       1
# 593  ENSG00000100138    NHP2L1   22  42069934  42086508      -1
# 594  ENSG00000167077      MEI1   22  42095503  42195460       1
# 595  ENSG00000100147   CCDC134   22  42196683  42222303       1
# 596  ENSG00000198911    SREBF2   22  42229109  42303312       1
#
#                type  entrezID      HUGO           pLI    ncRVIS  posMapSNPs  \
# 0    protein_coding  142678.0      MIB2  1.585433e-04  0.030973           4
# 1    protein_coding    8510.0    MMP23B           NaN       NaN           5
# 2    protein_coding  728642.0    CDK11B  7.282944e-01       NaN          34
# 3    protein_coding  728661.0  SLC35E2B  6.210025e-01 -0.794611          34
# 4    protein_coding    8764.0  TNFRSF14  8.199991e-01 -0.131268           1
# ..              ...       ...       ...           ...       ...         ...
# 592  protein_coding    2547.0     XRCC6  9.968559e-01 -0.128101           2
# 593  protein_coding    4809.0    NHP2L1  7.105853e-01  0.082226           2
# 594  protein_coding  150365.0      MEI1  1.215924e-08  0.500155          13
# 595  protein_coding   79879.0   CCDC134  7.411728e-04  0.324960          14
# 596  protein_coding    6721.0    SREBF2  9.962716e-01  0.410467          11
#
#      posMapMaxCADD      minGwasP   IndSigSNPs GenomicLocus
# 0            3.164           NaN  rs115866895            1
# 1            3.164           NaN  rs115866895            1
# 2           11.560  1.617240e-15  rs115866895            1
# 3           11.560  1.617240e-15  rs115866895            1
# 4            1.637           NaN    rs4648450            2
# ..             ...           ...          ...          ...
# 592          6.981           NaN   rs28489620          314
# 593          6.981           NaN   rs28489620          314
# 594          8.496           NaN   rs28489620          314
# 595          8.496           NaN   rs28489620          314
# 596          8.328           NaN   rs28489620          314
#
# [597 rows x 16 columns]

# %% [markdown]
# ### Construct the PCAs in terms of Genes

# %%
gene_pca_dict = {} #pd.DataFrame(index = genes_df.symbol.values)
# Get the possible PCAs
pc_gene_ours_df = genes_df.loc[:,["IndSigSNPs","symbol"]]
pc_gene_ours_with_exp_df = genes_df.loc[:,["IndSigSNPs","symbol"]]
pc_gene_pap_df = genes_df.loc[:,["IndSigSNPs","symbol"]]
pc_gene_dict = {"pap": pc_gene_pap_df,
                "ours": pc_gene_ours_df,
                "ours_with_exp": pc_gene_ours_with_exp_df}
pc_dict = {"pap": pc_pap_df,
            "ours": pc_ours_df,
            "ours_with_exp": pc_ours_with_exp_df}

# %%
for lab in pc_gene_dict.keys():
   pc_gene_df = pc_gene_dict[lab]
   pc_df = pc_dict[lab]
   pc_gene_df[pc_df.columns] = 0.0
   for snp in pc_gene_df.IndSigSNPs:
      if ";" in snp:
         snp_list = list(snp.split(";"))
      else: snp_list = [snp]
      for pc_col in pc_df.columns:
         for snp in snp_list:
            gene_rows = list(pc_gene_df[pc_gene_df["IndSigSNPs"]==snp].index)
            pc_gene_df.loc[gene_rows, pc_col] = pc_df.loc[snp, pc_col]
pc_gene_df
# Out:
#       IndSigSNPs    symbol       pc_1      pc_2
# 0    rs115866895      MIB2  -6.436117  0.075144
# 1    rs115866895    MMP23B  -6.436117  0.075144
# 2    rs115866895    CDK11B  -6.436117  0.075144
# 3    rs115866895  SLC35E2B  -6.436117  0.075144
# 4      rs4648450  TNFRSF14 -10.560462 -1.307634
# ..           ...       ...        ...       ...
# 592   rs28489620     XRCC6  -6.469766  7.800513
# 593   rs28489620    NHP2L1  -6.469766  7.800513
# 594   rs28489620      MEI1  -6.469766  7.800513
# 595   rs28489620   CCDC134  -6.469766  7.800513
# 596   rs28489620    SREBF2  -6.469766  7.800513
#
# [597 rows x 4 columns]

# %% [markdown]
# ### Save the gene list

# %%
pc_gene_df.symbol.to_csv(path_dir+"/gene_list.csv", index = False, header=False)

# %% [markdown]
# #### Load the pathways found on reactome

# %%
reactome_pathways = pd.read_csv(path_dir+"/reactome_pathways.csv")
reactome_pathways["Submitted entities found"] = reactome_pathways["Submitted entities found"].str.split(";")
#reactome_pathways = reactome_pathways.explode("Submitted entities found")
len(reactome_pathways["Pathway name"].unique())
# Out:
# 1346

# %% [markdown]
# ### Group the genes by association
# In order to get pathway enrichment we need to be able to group the genes. For each principal componene group the genes by their association score.

# %%
for lab in pc_gene_dict.keys():
   pc_gene_df = pc_gene_dict[lab]
   pc_df = pc_dict[lab]
   for pc_col in pc_df.columns:
     groups = pd.cut(pc_gene_df[pc_col],
                     bins = 10,
                     labels = [pc_col+"_%d"%i for i in range(10)])
     groups_ranges = pd.cut(pc_gene_df[pc_col],
                     bins = 10)
     pc_gene_df[pc_col+"_bin"] = groups
     pc_gene_df[pc_col+"_bin_ranges"] = groups_ranges

# %% [markdown]
# ### Restructure the dataframe to have the bin labels as columns and genes as the values.

# %%
pc_gene_groups_dict = {}
bin_range_dict = {}
for lab in pc_gene_dict.keys():
   pc_gene_df = pc_gene_dict[lab]
   bin_groups = {}
   bin_ranges = {}
   for pc_col in pc_df.columns:
      for bin in pc_gene_df[pc_col +"_bin"].unique():
         genes = pc_gene_df.loc[pc_gene_df[pc_col+"_bin"]==bin,"symbol"]
         bin_groups[bin] = genes
         bin_ranges[bin] = {"mid": 
                            pc_gene_df.loc[pc_gene_df[pc_col+"_bin"]==bin,pc_col+"_bin_ranges"].values[0].mid,
                            "interval": pc_gene_df.loc[pc_gene_df[pc_col+"_bin"]==bin,pc_col+"_bin_ranges"].values[0]
         }
   pc_gene_groups_dict[lab] = pd.DataFrame(bin_groups)
   bin_range_dict[lab] = pd.DataFrame(bin_ranges).T
   #print(pc_gene_groups_dict[lab])
bin_range_dict
# Out:
# {'pap':            mid           interval
#  pc_1_4 -2.3055    (-3.271, -1.34]
#  pc_1_6  1.5555      (0.59, 2.521]
#  pc_1_3  -4.236   (-5.201, -3.271]
#  pc_1_7   3.486     (2.521, 4.451]
#  pc_1_0 -10.037  (-11.012, -9.062]
#  pc_1_8  5.4165     (4.451, 6.382]
#  pc_1_5  -0.375      (-1.34, 0.59]
#  pc_1_9   7.347     (6.382, 8.312]
#  pc_1_2 -6.1665   (-7.132, -5.201]
#  pc_1_1  -8.097   (-9.062, -7.132]
#  pc_2_6  3.4175     (2.357, 4.478]
#  pc_2_2 -5.0655   (-6.126, -4.005]
#  pc_2_5  1.2965     (0.236, 2.357]
#  pc_2_3  -2.945   (-4.005, -1.885]
#  pc_2_4 -0.8245    (-1.885, 0.236]
#  pc_2_1 -7.1865   (-8.247, -6.126]
#  pc_2_7   5.538     (4.478, 6.598]
#  pc_2_8  7.6585     (6.598, 8.719]
#  pc_2_0 -9.3175  (-10.388, -8.247]
#  pc_2_9  9.7795     (8.719, 10.84],
#  'ours':             mid            interval
#  pc_1_7    7.346      (5.881, 8.811]
#  pc_1_8  10.2765     (8.811, 11.742]
#  pc_1_2  -7.3075    (-8.773, -5.842]
#  pc_1_4 -1.44645    (-2.912, 0.0191]
#  pc_1_9  13.2075    (11.742, 14.673]
#  pc_1_0  -13.184  (-14.664, -11.704]
#  pc_1_1 -10.2385   (-11.704, -8.773]
#  pc_1_6   4.4155       (2.95, 5.881]
#  pc_1_3   -4.377    (-5.842, -2.912]
#  pc_1_5  1.48455      (0.0191, 2.95]
#  pc_2_5   0.3215      (-0.66, 1.303]
#  pc_2_6    2.284      (1.303, 3.265]
#  pc_2_1  -7.5275    (-8.509, -6.546]
#  pc_2_4   -1.641     (-2.622, -0.66]
#  pc_2_2   -5.565    (-6.546, -4.584]
#  pc_2_7    4.246      (3.265, 5.227]
#  pc_2_3   -3.603    (-4.584, -2.622]
#  pc_2_8   6.2085       (5.227, 7.19]
#  pc_2_0     -9.5   (-10.491, -8.509]
#  pc_2_9    8.171       (7.19, 9.152],
#  'ours_with_exp':             mid            interval
#  pc_1_2   -7.309     (-8.77, -5.848]
#  pc_1_1  -10.231    (-11.692, -8.77]
#  pc_1_7    7.301       (5.84, 8.762]
#  pc_1_5  1.45707   (-0.00386, 2.918]
#  pc_1_0 -13.1675  (-14.643, -11.692]
#  pc_1_9   13.145    (11.684, 14.606]
#  pc_1_8   10.223     (8.762, 11.684]
#  pc_1_3   -4.387    (-5.848, -2.926]
#  pc_1_6    4.379       (2.918, 5.84]
#  pc_1_4 -1.46493  (-2.926, -0.00386]
#  pc_2_4  -0.3255     (-1.314, 0.663]
#  pc_2_3  -2.3025    (-3.291, -1.314]
#  pc_2_8   7.5825      (6.594, 8.571]
#  pc_2_5   1.6515       (0.663, 2.64]
#  pc_2_7   5.6055      (4.617, 6.594]
#  pc_2_2  -4.2795    (-5.268, -3.291]
#  pc_2_6   3.6285       (2.64, 4.617]
#  pc_2_1  -6.2565    (-7.245, -5.268]
#  pc_2_9   9.5595     (8.571, 10.548]
#  pc_2_0  -8.2435    (-9.242, -7.245]}

# %% [markdown]
# ## ENRICHR
# ### Get the pathway association for gene sets in each cluster.
# Using the ENRICHR api get the pathways associated with the sets of SNPS in each cluster.

# %%
ENRICHR_add_URL = 'https://maayanlab.cloud/Enrichr/addList'
ENRICHR_URL = 'https://maayanlab.cloud/Enrichr/enrich'
gene_set_library = 'Enrichr_Users_Contributed_Lists_2020'
query_string = '?userListId=%s&backgroundType=%s'
path_clust_OR_dict ={}
path_clust_score_dict ={}
s= requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
s.mount('http://', adapter)
s.mount('https://', adapter)
user_ids_full_list = {}
for c_lab in cluster_method_labels:
    print(c_lab)
    clust_genes_df = gene_clust_dict[c_lab]
    c_num_labs = clust_genes_df.columns
    OR_list = []
    score_list = []
    user_ids_list = []
    all_list = []
    for c_num_lab in c_num_labs:
        try: c_num = int(c_num_lab[-1])
        except: break
        clust_cnum_genes = clust_genes_df.index[clust_genes_df[c_num_lab] == 1].tolist()
        genes_str = '\n'.join(clust_cnum_genes)
        description = c_lab + ' gene list'
        payload = {
            'list': (None, genes_str),
            'description': (None, description)
        }
        response = s.post(ENRICHR_add_URL, files=payload)
        if not response.ok:
            #raise Exception
            print('Error analyzing gene list')
        else:
            data = json.loads(response.text)
            #print(data)
            user_list_id = data['userListId']
            #print(user_list_id)
            user_ids_list.append(user_list_id)
            response = s.get(
            ENRICHR_URL + query_string % (user_list_id, gene_set_library)
            )
            if not response.ok:
                #raise Exception
                print('Error fetching enrichment results')
            else:
                data = json.loads(response.text)[gene_set_library]
                if len(data)>0:
                    for i in range(len(data)):
                        rank = data[i][0]
                        pathway = data[i][1]
                        pval = data[i][2]
                        OR = data[i][3]
                        score = data[i][4]
                        overlap_genes = data[i][5]
                        adjust_pval = data[i][6]
                        all_row = {"cluster_number": c_num,
                            "pathway": pathway,
                            "rank": rank,
                            "pval": pval, 
                            "adjusted_pval": adjust_pval,
                            "Odds_Ratio" : OR,
                            "combined_score": score,
                            "n_overlap": len(overlap_genes),
                            "overlap_genes": overlap_genes}
                        all_list.append(all_row)
                        OR_row = {"cluster_number": c_num,
                            "pathway": pathway,
                            "Odds_Ratio" : OR}
                        OR_list.append(OR_row)
                        score_row = {"cluster_number": c_num,
                                "pathway": pathway,
                                "combined_score": score}
                        score_list.append(score_row)
                else:
                    OR_row = {"cluster_number": c_num,
                              "pathway": "No_pathway"}
                    OR_list.append(OR_row)
                    score_row = {"cluster_number": c_num,
                              "pathway": "No_pathway"}
                    score_list.append(score_row)
    user_ids_full_list[c_lab] = user_ids_list
    OR_df = pd.DataFrame(OR_list)
    score_df = pd.DataFrame(score_list)
    all_df = pd.DataFrame(all_list)
    OR_df.to_csv(path_dir+"/clust_paths_OR_"+c_lab+".csv")
    score_df.to_csv(path_dir+"/clust_path_combined_score_"+c_lab+".csv")
    all_df.to_csv(path_dir+"/clust_path_enrichment_"+c_lab+".csv")
    path_clust_OR_dict[c_lab] = OR_df
    path_clust_score_dict[c_lab] = score_df
print(path_clust_score_dict)
# Out:
# KmeansLloydStdFourDarrous
# KmeansLloydStdSixDarrous
# KmeansElkanStdFourDarrous
# KmeansLloydStdFourProposed
# KmeansLloydStdSixProposed
# KmeansElkanStdFourProposed
# KmedoidsEuclideanProposedFour
# KmeansCosineSixProposed
# DBScanZeroProposed
# DBScanOneProposed
# DBScanTwoProposed
# KmeansCosineMinibatchSixProposed
# KmedoidsCosineSixProposed
# GMMZeroProposed
# GMMOneProposed
# BirchZeroProposed
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# Error analyzing gene list
# BirchOneProposed
# BirchTwoProposed
# KmeansCosineTwoMinAICProposed
# KmedoidsCosineThreeMinAICProposed
# {'KmeansLloydStdFourDarrous':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  https://science.sciencemag.org/content/365/645...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                             ct1346
# 4                  1                                       inflammation
# ...              ...                                                ...
# 3676               3      Blue module gene list CRC (Normal and Cancer)
# 3677               3  Bacteria translocation, dataset: 4b799ecdbaaed...
# 3678               3  Skin Cutaneous Melanoma under expressed genes ...
# 3679               3                    MEF-iPS diff ES DNA methylation
# 3680               3                                     pred all genes
#
#       combined_score
# 0        1570.396478
# 1          78.826549
# 2          64.018741
# 3          31.637536
# 4         155.274597
# ...              ...
# 3676        0.000647
# 3677        0.000866
# 3678        0.000412
# 3679        0.000056
# 3680        0.000179
#
# [3681 rows x 3 columns], 'KmeansLloydStdSixDarrous':       cluster_number                                            pathway  \
# 0                  4  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  4  https://science.sciencemag.org/content/365/645...
# 2                  4                                 az mlm p <.01+ WES
# 3                  4         Genes that were expressed and up regulated
# 4                  4                            microRNA in tubercuosis
# ...              ...                                                ...
# 4887               1  downregulated, dataset: 6d5ee3258f0d93c3f9f758...
# 4888               1      Blue module gene list CRC (Normal and Cancer)
# 4889               1                                         down in VS
# 4890               1                      Upregulated genes in WT brain
# 4891               1  Bacteria translocation, dataset: 4b799ecdbaaed...
#
#       combined_score
# 0         249.540670
# 1          77.589755
# 2          53.588404
# 3          34.728597
# 4          96.147289
# ...              ...
# 4887        0.001711
# 4888        0.001356
# 4889        0.002198
# 4890        0.000217
# 4891        0.000090
#
# [4892 rows x 3 columns], 'KmeansElkanStdFourDarrous':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  https://science.sciencemag.org/content/365/645...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                             ct1346
# 4                  1                                       inflammation
# ...              ...                                                ...
# 3676               3      Blue module gene list CRC (Normal and Cancer)
# 3677               3  Bacteria translocation, dataset: 4b799ecdbaaed...
# 3678               3  Skin Cutaneous Melanoma under expressed genes ...
# 3679               3                    MEF-iPS diff ES DNA methylation
# 3680               3                                     pred all genes
#
#       combined_score
# 0        1570.396478
# 1          78.826549
# 2          64.018741
# 3          31.637536
# 4         155.274597
# ...              ...
# 3676        0.000647
# 3677        0.000866
# 3678        0.000412
# 3679        0.000056
# 3680        0.000179
#
# [3681 rows x 3 columns], 'KmeansLloydStdFourProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1                                       inflammation
# 2                  1         Genes that were expressed and up regulated
# 3                  1  10 percent of the longest transcripts of the h...
# 4                  1                                      wound healing
# ...              ...                                                ...
# 3728               2  Skin Cutaneous Melanoma under expressed genes ...
# 3729               2                                         harvard hw
# 3730               2                                     pred all genes
# 3731               2                    MEF-iPS diff ES DNA methylation
# 3732               2  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        1154.462333
# 1         441.018853
# 2          27.891232
# 3          21.645860
# 4          52.483056
# ...              ...
# 3728        0.002268
# 3729        0.000202
# 3730        0.000363
# 3731        0.000014
# 3732        0.000018
#
# [3733 rows x 3 columns], 'KmeansLloydStdSixProposed':       cluster_number                                            pathway  \
# 0                  2  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  2                                       inflammation
# 2                  2  10 percent of the longest transcripts of the h...
# 3                  2         Genes that were expressed and up regulated
# 4                  2                                      wound healing
# ...              ...                                                ...
# 4851               5                                        Sca1+ genes
# 4852               5                                             Cn1346
# 4853               5  Meta-analysis of autosomal sex DE genes across...
# 4854               5  Turquise module gene list CRC (Normal and Cancer)
# 4855               5                                     pred all genes
#
#       combined_score
# 0         949.152361
# 1         543.341293
# 2          21.411208
# 3          26.387780
# 4          66.847971
# ...              ...
# 4851        0.003640
# 4852        0.003683
# 4853        0.001738
# 4854        0.000622
# 4855        0.000752
#
# [4856 rows x 3 columns], 'KmeansElkanStdFourProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1                                       inflammation
# 2                  1         Genes that were expressed and up regulated
# 3                  1  10 percent of the longest transcripts of the h...
# 4                  1                                      wound healing
# ...              ...                                                ...
# 3728               2  Skin Cutaneous Melanoma under expressed genes ...
# 3729               2                                         harvard hw
# 3730               2                                     pred all genes
# 3731               2                    MEF-iPS diff ES DNA methylation
# 3732               2  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        1154.462333
# 1         441.018853
# 2          27.891232
# 3          21.645860
# 4          52.483056
# ...              ...
# 3728        0.002268
# 3729        0.000202
# 3730        0.000363
# 3731        0.000014
# 3732        0.000018
#
# [3733 rows x 3 columns], 'KmedoidsEuclideanProposedFour':       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0                                       inflammation
# 2                  0  10 percent of the longest transcripts of the h...
# 3                  0                                        Gdgtdrhyjgk
# 4                  0                 viral chromatin associated factors
# ...              ...                                                ...
# 3706               2                                   wte deg analysis
# 3707               2  Breast cancer possibly correlated genes after ...
# 3708               2  Skin Cutaneous Melanoma under expressed genes ...
# 3709               2                    MEF-iPS diff ES DNA methylation
# 3710               2  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        1605.217526
# 1         283.031318
# 2          26.180243
# 3          33.230975
# 4          31.991884
# ...              ...
# 3706        0.001036
# 3707        0.000687
# 3708        0.000808
# 3709        0.000252
# 3710        0.000107
#
# [3711 rows x 3 columns], 'KmeansCosineSixProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  Genes closest to the lead SNPs from Ben Neale'...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                        Gdgtdrhyjgk
# 4                  1  genes closest to lead SNPs from Neale analysis...
# ...              ...                                                ...
# 4916               4  Turquise module gene list CRC (Normal and Cancer)
# 4917               4                          282+/282-, dataset: 70v5q
# 4918               4                                         Mizosample
# 4919               4                          282+/282-, dataset: 70uej
# 4920               4                                        Sca1+ genes
#
#       combined_score
# 0        3204.063433
# 1         303.992195
# 2          39.366311
# 3          37.796644
# 4          65.531825
# ...              ...
# 4916        0.002602
# 4917        0.002281
# 4918        0.001043
# 4919        0.000876
# 4920        0.000006
#
# [4921 rows x 3 columns], 'DBScanZeroProposed':       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                       inflammation
# 3                  0  https://science.sciencemag.org/content/365/645...
# 4                  0  Genes closest to the lead SNPs from Ben Neale'...
# ...              ...                                                ...
# 2978               1      Blue module gene list CRC (Normal and Cancer)
# 2979               1                         All Gap probes upregulated
# 2980               1                          pathway enrichment celiac
# 2981               1  Turquise module gene list CRC (Normal and Cancer)
# 2982               1                    MEF-iPS diff ES DNA methylation
#
#       combined_score
# 0        7516.478683
# 1         116.826333
# 2         350.228425
# 3          40.974086
# 4         194.777510
# ...              ...
# 2978        0.000262
# 2979        0.000175
# 2980        0.000111
# 2981        0.000012
# 2982        0.000002
#
# [2983 rows x 3 columns], 'DBScanOneProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  https://science.sciencemag.org/content/365/645...
# 3                  1  genes closest to lead SNPs from Neale analysis...
# 4                  1                                        Gdgtdrhyjgk
# ...              ...                                                ...
# 1245               1                                     pred all genes
# 1246               1  Bacteria translocation, dataset: 4b799ecdbaaed...
# 1247               1      Blue module gene list CRC (Normal and Cancer)
# 1248               1  Turquise module gene list CRC (Normal and Cancer)
# 1249               1                    MEF-iPS diff ES DNA methylation
#
#       combined_score
# 0        9670.786612
# 1         108.507651
# 2          52.016270
# 3          91.678083
# 4          39.257677
# ...              ...
# 1245        0.000026
# 1246        0.000019
# 1247        0.000002
# 1248        0.000001
# 1249        0.000001
#
# [1250 rows x 3 columns], 'DBScanTwoProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  https://science.sciencemag.org/content/365/645...
# 3                  1  genes closest to lead SNPs from Neale analysis...
# 4                  1                                        Gdgtdrhyjgk
# ...              ...                                                ...
# 1245               1                                     pred all genes
# 1246               1  Bacteria translocation, dataset: 4b799ecdbaaed...
# 1247               1      Blue module gene list CRC (Normal and Cancer)
# 1248               1  Turquise module gene list CRC (Normal and Cancer)
# 1249               1                    MEF-iPS diff ES DNA methylation
#
#       combined_score
# 0        9670.786612
# 1         108.507651
# 2          52.016270
# 3          91.678083
# 4          39.257677
# ...              ...
# 1245        0.000026
# 1246        0.000019
# 1247        0.000002
# 1248        0.000001
# 1249        0.000001
#
# [1250 rows x 3 columns], 'KmeansCosineMinibatchSixProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  genes closest to lead SNPs from Neale analysis...
# 3                  1  Genes closest to the lead SNPs from Ben Neale'...
# 4                  1  https://science.sciencemag.org/content/365/645...
# ...              ...                                                ...
# 4462               5                                       wild vs pale
# 4463               5  CD1 female mice adults - gestational CdCl2 vs ...
# 4464               5                                   Msc Role Disease
# 4465               5                                             ct1346
# 4466               5                Rheumatiod arthritis trasnscriptome
#
#       combined_score
# 0        5952.375754
# 1         106.999496
# 2          81.248532
# 3         207.630169
# 4          38.332528
# ...              ...
# 4462        0.339474
# 4463        0.336937
# 4464        0.310167
# 4465        0.287661
# 4466        0.203385
#
# [4467 rows x 3 columns], 'KmedoidsCosineSixProposed':       cluster_number                                            pathway  \
# 0                  3  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  3                                       inflammation
# 2                  3  10 percent of the longest transcripts of the h...
# 3                  3                                        Gdgtdrhyjgk
# 4                  3                 viral chromatin associated factors
# ...              ...                                                ...
# 4373               4                                      hola tomatito
# 4374               4                                         scc-cx HDE
# 4375               4                                      Endometriosis
# 4376               4                                        Sca1+ genes
# 4377               4                                              Rthth
#
#       combined_score
# 0        1605.217526
# 1         283.031318
# 2          26.180243
# 3          33.230975
# 4          31.991884
# ...              ...
# 4373        0.037355
# 4374        0.032609
# 4375        0.031014
# 4376        0.022757
# 4377        0.014559
#
# [4378 rows x 3 columns], 'GMMZeroProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1  The genes about major depressive disorder anal...
# 4                  1  Genes closest to the lead SNPs from Ben Neale'...
# ...              ...                                                ...
# 2969               2                          pathway enrichment celiac
# 2970               2                    MEF-iPS diff ES DNA methylation
# 2971               2      Blue module gene list CRC (Normal and Cancer)
# 2972               2                                     pred all genes
# 2973               2  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        4740.450033
# 1          83.271456
# 2          51.791646
# 3          78.605707
# 4         199.716664
# ...              ...
# 2969        0.000545
# 2970        0.000203
# 2971        0.000095
# 2972        0.000074
# 2973        0.000001
#
# [2974 rows x 3 columns], 'GMMOneProposed':       cluster_number                                            pathway  \
# 0                  4  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  4                                       inflammation
# 2                  4  The genes about major depressive disorder anal...
# 3                  4  10 percent of the longest transcripts of the h...
# 4                  4         Genes that were expressed and up regulated
# ...              ...                                                ...
# 3993               3  Identification of the novel conserved transcri...
# 3994               3                   GSE140581 p65 LPS peaks from GEO
# 3995               3   HPV-cervical cancer up-regulated genes vs Normal
# 3996               3                                         DEG of ZZW
# 3997               3                                             ct1346
#
#       combined_score
# 0        1761.487115
# 1         530.789489
# 2          52.367357
# 3          20.339658
# 4          25.334638
# ...              ...
# 3993        0.001449
# 3994        0.001377
# 3995        0.001240
# 3996        0.001004
# 3997        0.001075
#
# [3998 rows x 3 columns], 'BirchZeroProposed':        cluster_number                                            pathway  \
# 0                   7                                   High in human RG
# 1                   7                                           PAH test
# 2                   7                                    Phosphopeptides
# 3                   7                                           Als Gene
# 4                   7                      Nextera rapid capture targets
# ...               ...                                                ...
# 18277               4                                   mir target genes
# 18278               4               TargetScanV7 135b target All targets
# 18279               4  Skin Cutaneous Melanoma under expressed genes ...
# 18280               4                          ARP1 WT vs E6 UTX binding
# 18281               4  shRNA knockdown of ARNT using TRC00003816 plas...
#
#        combined_score
# 0          627.742397
# 1          220.093038
# 2          543.359329
# 3           81.249580
# 4           81.249580
# ...               ...
# 18277        0.034145
# 18278        0.033001
# 18279        0.028588
# 18280        0.026140
# 18281        0.021655
#
# [18282 rows x 3 columns], 'BirchOneProposed':       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                        Gdgtdrhyjgk
# 3                  0                                       inflammation
# 4                  0                                        brain pleio
# ...              ...                                                ...
# 2214               1                          pathway enrichment celiac
# 2215               1                    MEF-iPS diff ES DNA methylation
# 2216               1      Blue module gene list CRC (Normal and Cancer)
# 2217               1                                     pred all genes
# 2218               1  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        4196.712210
# 1          77.340450
# 2          34.572409
# 3         145.170113
# 4          40.849789
# ...              ...
# 2214        0.000545
# 2215        0.000203
# 2216        0.000095
# 2217        0.000074
# 2218        0.000001
#
# [2219 rows x 3 columns], 'BirchTwoProposed':       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                        Gdgtdrhyjgk
# 3                  0                                       inflammation
# 4                  0                                        brain pleio
# ...              ...                                                ...
# 2214               1                          pathway enrichment celiac
# 2215               1                    MEF-iPS diff ES DNA methylation
# 2216               1      Blue module gene list CRC (Normal and Cancer)
# 2217               1                                     pred all genes
# 2218               1  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        4196.712210
# 1          77.340450
# 2          34.572409
# 3         145.170113
# 4          40.849789
# ...              ...
# 2214        0.000545
# 2215        0.000203
# 2216        0.000095
# 2217        0.000074
# 2218        0.000001
#
# [2219 rows x 3 columns], 'KmeansCosineTwoMinAICProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1                                       inflammation
# 4                  1                                        brain pleio
# ...              ...                                                ...
# 2214               0                          pathway enrichment celiac
# 2215               0                    MEF-iPS diff ES DNA methylation
# 2216               0      Blue module gene list CRC (Normal and Cancer)
# 2217               0                                     pred all genes
# 2218               0  Turquise module gene list CRC (Normal and Cancer)
#
#       combined_score
# 0        4196.712210
# 1          77.340450
# 2          34.572409
# 3         145.170113
# 4          40.849789
# ...              ...
# 2214        0.000545
# 2215        0.000203
# 2216        0.000095
# 2217        0.000074
# 2218        0.000001
#
# [2219 rows x 3 columns], 'KmedoidsCosineThreeMinAICProposed':       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1                                       inflammation
# 4                  1                                        brain pleio
# ...              ...                                                ...
# 2872               0                                Osteoclast specific
# 2873               0                              INTERACTOMIC ANALYSIS
# 2874               0                                         Mizosample
# 2875               0                                     kp vs wt 1.5fc
# 2876               0   HPV-cervical cancer up-regulated genes vs Normal
#
#       combined_score
# 0        4196.712210
# 1          77.340450
# 2          34.572409
# 3         145.170113
# 4          40.849789
# ...              ...
# 2872        0.003139
# 2873        0.002761
# 2874        0.002761
# 2875        0.001441
# 2876        0.000145
#
# [2877 rows x 3 columns]}

# %% [markdown]
# ### Get the pathway association for gene sets in each PCA bin

# %%
gene_set_library = 'Enrichr_Users_Contributed_Lists_2020'
query_string = '?userListId=%s&backgroundType=%s'
path_pca_OR_dict ={}
path_pca_score_dict ={}
path_pca_adj_score_dict = {}
s= requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
s.mount('http://', adapter)
s.mount('https://', adapter)
user_ids_full_list = {}
for lab in pc_gene_groups_dict.keys():
    pc_genes_df = pc_gene_groups_dict[lab]
    bin_labs = pc_genes_df.columns
    OR_list = []
    score_list = []
    adj_score_list = []
    user_ids_list = []
    all_list = []
    for bin in bin_labs:
        bin_genes = pc_genes_df[bin].dropna(axis=0).tolist()
        bin_mid = bin_range_dict[lab].loc[bin,"mid"]
        genes_str = '\n'.join(bin_genes)
        description = bin + ' gene list'
        payload = {
            'list': (None, genes_str),
            'description': (None, description)
        }
        response = s.post(ENRICHR_add_URL, files=payload)
        if not response.ok:
            #raise Exception
            print('Error analyzing gene list')
        else:
            data = json.loads(response.text)
            #print(data)
            user_list_id = data['userListId']
            #print(user_list_id)
            user_ids_list.append(user_list_id)
            response = s.get(
            ENRICHR_URL + query_string % (user_list_id, gene_set_library)
            )
            if not response.ok:
                #raise Exception
                print('Error fetching enrichment results')
            else:
                data = json.loads(response.text)[gene_set_library]
                if len(data)>0:
                    for i in range(len(data)):
                        rank = data[i][0]
                        pathway = data[i][1]
                        pval = data[i][2]
                        OR = data[i][3]
                        score = data[i][4]
                        adj_score = score*bin_mid
                        overlap_genes = data[i][5]
                        adjust_pval = data[i][6]
                        all_row = {"bin": bin,
                            "pathway": pathway,
                            "rank": rank,
                            "pval": pval, 
                            "adjusted_pval": adjust_pval,
                            "Odds_Ratio" : OR,
                            "combined_score": score,
                            "adjusted_score": adj_score,
                            "n_overlap": len(overlap_genes),
                            "overlap_genes": overlap_genes}
                        all_list.append(all_row)
                        OR_row = {"bin": bin,
                            "pathway": pathway,
                            "Odds_Ratio" : OR}
                        OR_list.append(OR_row)
                        score_row = {"bin": bin,
                                "pathway": pathway,
                                "combined_score": score}
                        score_list.append(score_row)
                        adj_score_row = {"bin": bin,
                                "pathway": pathway,
                                "adjusted_score": adj_score}
                        adj_score_list.append(adj_score_row)
                else:
                    OR_row = {"bin": bin,
                              "pathway": "No_pathway"}
                    OR_list.append(OR_row)
                    score_row = {"bin": bin,
                              "pathway": "No_pathway"}
                    score_list.append(score_row)
                    adj_score_row = {"bin": bin,
                              "pathway": "No_pathway"}
                    adj_score_list.append(adj_score_row)
    user_ids_full_list[bin] = user_ids_list
    OR_df = pd.DataFrame(OR_list)
    score_df = pd.DataFrame(score_list)
    all_df = pd.DataFrame(all_list)
    adj_score_df = pd.DataFrame(adj_score_list)
    OR_df.to_csv(path_dir+"/pca_paths_OR_"+lab+".csv")
    score_df.to_csv(path_dir+"/pca_path_combined_score_"+lab+".csv")
    all_df.to_csv(path_dir+"/pca_path_enrichment_"+lab+".csv")
    adj_score_df.to_csv(path_dir + "/pca_path_adj_score"+lab+".csv")
    path_pca_OR_dict[lab] = OR_df
    path_pca_score_dict[lab] = score_df
    path_pca_adj_score_dict[lab] = adj_score_df

# %%
# OFFLINE VERSION - load latest 
path_clust_OR_dict = {}
path_clust_score_dict = {}
user_ids_full_list = {}
for c_lab in cluster_method_labels:
    clust_genes_df = gene_clust_dict[c_lab]
    OR_df = pd.read_csv(path_dir+"/clust_paths_OR_"+c_lab+".csv", index_col=0)
    score_df = pd.read_csv(path_dir+"/clust_path_combined_score_"+c_lab+".csv", index_col=0)
    all_df = pd.read_csv(path_dir+"/clust_path_enrichment_"+c_lab+".csv", index_col=0)
    path_clust_OR_dict[c_lab] = OR_df
    path_clust_score_dict[c_lab] = score_df

# %% [markdown]
# # Filter the dominant pathways for each cluster.
# Get the top fifty pathways overall for each cluster method by `combined score` and `odds_ratio`.
# Also get the top 5 pathways per cluster by `combined_score` and `odds_ratio`.
#
# The odds ratio is computed using this formula:
#
# $$ oddsRatio = \frac{1.0 * a * d}{max(1.0 * b * c, 1)}$$
#
# where: a are the overlapping genes, b are the genes in the annotated set - overlapping genes, c- are the genes in the input set - overlapping genes, and d- are the 20,000 genes (or total genes in the background) - genes in the annotated set - genes in the input set + overlapping genes
#
# Finally, the combined score is a combination of the p-value and odds ratio calculated by multiplying the two scores as follows:
#
# $$ c = -log(p) * \text{oddsRatio} $$
# Where c is the combined score, p is the p-value computed using Fisher's exact test, and oddsRatio is the odds ratio. The combined score provides a compromise between both methods and in several benchmarks we show that it reports the best rankings when compared with the other scoring schemes.
#
# Enrichr provides all four options for sorting enriched terms.

# %%
c_lab = cluster_method_labels[0]
print(path_clust_OR_dict[c_lab])
# Out:
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  https://science.sciencemag.org/content/365/645...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                             ct1346
# 4                  1                                       inflammation
# ...              ...                                                ...
# 3676               3      Blue module gene list CRC (Normal and Cancer)
# 3677               3  Bacteria translocation, dataset: 4b799ecdbaaed...
# 3678               3  Skin Cutaneous Melanoma under expressed genes ...
# 3679               3                    MEF-iPS diff ES DNA methylation
# 3680               3                                     pred all genes
#
#       Odds_Ratio
# 0      21.038178
# 1       4.110373
# 2       3.457802
# 3       2.345616
# 4      17.413263
# ...          ...
# 3676    0.240561
# 3677    0.328778
# 3678    0.451822
# 3679    0.126142
# 3680    0.437391
#
# [3681 rows x 3 columns]

# %%
path_tops_dict = {}
top_five_lab = "TopFive"
top_fifty_lab = "TopFifty"
score_lab = "CombinedScore"
OR_lab = "OddsRatio"
for lab in cluster_method_labels:
    print(lab)
    print(path_clust_OR_dict[lab])
    sorted_df = path_clust_OR_dict[lab].sort_values(by=OR_lab, ascending=False)
    df_wide = sorted_df.pivot_table(index='pathway', columns='cluster_number', values=OR_lab)
    ind_list = df_wide.index
    col_list = df_wide.columns
    df_wide = pd.DataFrame(data = np.nan_to_num(df_wide),
                           index=ind_list,
                           columns = col_list)
    df_long= pd.melt(df_wide, ignore_index=False, value_name=OR_lab)
    df_long= df_long.reset_index().sort_values(by=OR_lab, ascending=False)
    top_fifty_byOR_df = df_long.head(50)
    top_five_perclust_df = df_long.groupby("cluster_number").head(5)
    OR_dict = {top_five_lab:top_five_perclust_df, top_fifty_lab:top_fifty_byOR_df}
    sorted_df = path_clust_score_dict[lab].sort_values(by=score_lab, ascending=False)
    df_wide = sorted_df.pivot_table(index='pathway', columns='cluster_number', values=score_lab)
    ind_list = df_wide.index
    col_list = df_wide.columns
    df_wide = pd.DataFrame(data = np.nan_to_num(df_wide),
                           index=ind_list,
                           columns = col_list)
    df_long= pd.melt(df_wide, ignore_index=False, value_name=score_lab)
    df_long= df_long.reset_index().sort_values(by=score_lab, ascending=False)
    top_fifty_byscore_df = df_long.head(50)
    top_five_perclust_df = df_long.groupby("cluster_number").head(5)
    score_dict = {top_five_lab:top_five_perclust_df, top_fifty_lab:top_fifty_byscore_df}
    path_tops_dict[lab] = {OR_lab:OR_dict, score_lab:score_dict}
# Out:
# KmeansLloydStdFourDarrous
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  https://science.sciencemag.org/content/365/645...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                             ct1346
# 4                  1                                       inflammation
# ...              ...                                                ...
# 3676               3      Blue module gene list CRC (Normal and Cancer)
# 3677               3  Bacteria translocation, dataset: 4b799ecdbaaed...
# 3678               3  Skin Cutaneous Melanoma under expressed genes ...
# 3679               3                    MEF-iPS diff ES DNA methylation
# 3680               3                                     pred all genes
#
#       Odds_Ratio
# 0      21.038178
# 1       4.110373
# 2       3.457802
# 3       2.345616
# 4      17.413263
# ...          ...
# 3676    0.240561
# 3677    0.328778
# 3678    0.451822
# 3679    0.126142
# 3680    0.437391
#
# [3681 rows x 3 columns]
# KmeansLloydStdSixDarrous
#       cluster_number                                            pathway  \
# 0                  4  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  4  https://science.sciencemag.org/content/365/645...
# 2                  4                                 az mlm p <.01+ WES
# 3                  4         Genes that were expressed and up regulated
# 4                  4                            microRNA in tubercuosis
# ...              ...                                                ...
# 4887               1  downregulated, dataset: 6d5ee3258f0d93c3f9f758...
# 4888               1      Blue module gene list CRC (Normal and Cancer)
# 4889               1                                         down in VS
# 4890               1                      Upregulated genes in WT brain
# 4891               1  Bacteria translocation, dataset: 4b799ecdbaaed...
#
#       Odds_Ratio
# 0       9.788691
# 1       4.431897
# 2       4.337006
# 3       3.507938
# 4      12.422306
# ...          ...
# 4887    0.204902
# 4888    0.196770
# 4889    0.425578
# 4890    0.148564
# 4891    0.132257
#
# [4892 rows x 3 columns]
# KmeansElkanStdFourDarrous
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  https://science.sciencemag.org/content/365/645...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                             ct1346
# 4                  1                                       inflammation
# ...              ...                                                ...
# 3676               3      Blue module gene list CRC (Normal and Cancer)
# 3677               3  Bacteria translocation, dataset: 4b799ecdbaaed...
# 3678               3  Skin Cutaneous Melanoma under expressed genes ...
# 3679               3                    MEF-iPS diff ES DNA methylation
# 3680               3                                     pred all genes
#
#       Odds_Ratio
# 0      21.038178
# 1       4.110373
# 2       3.457802
# 3       2.345616
# 4      17.413263
# ...          ...
# 3676    0.240561
# 3677    0.328778
# 3678    0.451822
# 3679    0.126142
# 3680    0.437391
#
# [3681 rows x 3 columns]
# KmeansLloydStdFourProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1                                       inflammation
# 2                  1         Genes that were expressed and up regulated
# 3                  1  10 percent of the longest transcripts of the h...
# 4                  1                                      wound healing
# ...              ...                                                ...
# 3728               2  Skin Cutaneous Melanoma under expressed genes ...
# 3729               2                                         harvard hw
# 3730               2                                     pred all genes
# 3731               2                    MEF-iPS diff ES DNA methylation
# 3732               2  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      18.251224
# 1      28.640828
# 2       3.091057
# 3       2.419499
# 4       7.392817
# ...          ...
# 3728    0.551057
# 3729    0.148748
# 3730    0.490941
# 3731    0.108477
# 3732    0.205006
#
# [3733 rows x 3 columns]
# KmeansLloydStdSixProposed
#       cluster_number                                            pathway  \
# 0                  2  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  2                                       inflammation
# 2                  2  10 percent of the longest transcripts of the h...
# 3                  2         Genes that were expressed and up regulated
# 4                  2                                      wound healing
# ...              ...                                                ...
# 4851               5                                        Sca1+ genes
# 4852               5                                             Cn1346
# 4853               5  Meta-analysis of autosomal sex DE genes across...
# 4854               5  Turquise module gene list CRC (Normal and Cancer)
# 4855               5                                     pred all genes
#
#       Odds_Ratio
# 0      17.691123
# 1      33.404769
# 2       2.503425
# 3       3.160211
# 4       8.611982
# ...          ...
# 4851    0.478981
# 4852    0.511611
# 4853    0.272446
# 4854    0.237482
# 4855    0.416957
#
# [4856 rows x 3 columns]
# KmeansElkanStdFourProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1                                       inflammation
# 2                  1         Genes that were expressed and up regulated
# 3                  1  10 percent of the longest transcripts of the h...
# 4                  1                                      wound healing
# ...              ...                                                ...
# 3728               2  Skin Cutaneous Melanoma under expressed genes ...
# 3729               2                                         harvard hw
# 3730               2                                     pred all genes
# 3731               2                    MEF-iPS diff ES DNA methylation
# 3732               2  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      18.251224
# 1      28.640828
# 2       3.091057
# 3       2.419499
# 4       7.392817
# ...          ...
# 3728    0.551057
# 3729    0.148748
# 3730    0.490941
# 3731    0.108477
# 3732    0.205006
#
# [3733 rows x 3 columns]
# KmedoidsEuclideanProposedFour
#       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0                                       inflammation
# 2                  0  10 percent of the longest transcripts of the h...
# 3                  0                                        Gdgtdrhyjgk
# 4                  0                 viral chromatin associated factors
# ...              ...                                                ...
# 3706               2                                   wte deg analysis
# 3707               2  Breast cancer possibly correlated genes after ...
# 3708               2  Skin Cutaneous Melanoma under expressed genes ...
# 3709               2                    MEF-iPS diff ES DNA methylation
# 3710               2  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      18.798968
# 1      20.805400
# 2       2.373728
# 3       3.032666
# 4       2.983293
# ...          ...
# 3706    0.256050
# 3707    0.287932
# 3708    0.508820
# 3709    0.215704
# 3710    0.271657
#
# [3711 rows x 3 columns]
# KmeansCosineSixProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  Genes closest to the lead SNPs from Ben Neale'...
# 2                  1  10 percent of the longest transcripts of the h...
# 3                  1                                        Gdgtdrhyjgk
# 4                  1  genes closest to lead SNPs from Neale analysis...
# ...              ...                                                ...
# 4916               4  Turquise module gene list CRC (Normal and Cancer)
# 4917               4                          282+/282-, dataset: 70v5q
# 4918               4                                         Mizosample
# 4919               4                          282+/282-, dataset: 70uej
# 4920               4                                        Sca1+ genes
#
#       Odds_Ratio
# 0      37.788260
# 1      24.419720
# 2       3.374674
# 3       3.990012
# 4       7.143791
# ...          ...
# 4916    0.287892
# 4917    0.282298
# 4918    0.252774
# 4919    0.290352
# 4920    0.180007
#
# [4921 rows x 3 columns]
# DBScanZeroProposed
#       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                       inflammation
# 3                  0  https://science.sciencemag.org/content/365/645...
# 4                  0  Genes closest to the lead SNPs from Ben Neale'...
# ...              ...                                                ...
# 2978               1      Blue module gene list CRC (Normal and Cancer)
# 2979               1                         All Gap probes upregulated
# 2980               1                          pathway enrichment celiac
# 2981               1  Turquise module gene list CRC (Normal and Cancer)
# 2982               1                    MEF-iPS diff ES DNA methylation
#
#       Odds_Ratio
# 0      52.200359
# 1       4.602693
# 2      27.205318
# 3       3.492887
# 4      17.751522
# ...          ...
# 2978    0.261040
# 2979    0.207642
# 2980    0.197931
# 2981    0.229874
# 2982    0.090859
#
# [2983 rows x 3 columns]
# DBScanOneProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  https://science.sciencemag.org/content/365/645...
# 3                  1  genes closest to lead SNPs from Neale analysis...
# 4                  1                                        Gdgtdrhyjgk
# ...              ...                                                ...
# 1245               1                                     pred all genes
# 1246               1  Bacteria translocation, dataset: 4b799ecdbaaed...
# 1247               1      Blue module gene list CRC (Normal and Cancer)
# 1248               1  Turquise module gene list CRC (Normal and Cancer)
# 1249               1                    MEF-iPS diff ES DNA methylation
#
#       Odds_Ratio
# 0      30.461852
# 1       2.709316
# 2       2.431063
# 3       4.414697
# 4       2.385412
# ...          ...
# 1245    0.646030
# 1246    0.496040
# 1247    0.317589
# 1248    0.261591
# 1249    0.250096
#
# [1250 rows x 3 columns]
# DBScanTwoProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  https://science.sciencemag.org/content/365/645...
# 3                  1  genes closest to lead SNPs from Neale analysis...
# 4                  1                                        Gdgtdrhyjgk
# ...              ...                                                ...
# 1245               1                                     pred all genes
# 1246               1  Bacteria translocation, dataset: 4b799ecdbaaed...
# 1247               1      Blue module gene list CRC (Normal and Cancer)
# 1248               1  Turquise module gene list CRC (Normal and Cancer)
# 1249               1                    MEF-iPS diff ES DNA methylation
#
#       Odds_Ratio
# 0      30.461852
# 1       2.709316
# 2       2.431063
# 3       4.414697
# 4       2.385412
# ...          ...
# 1245    0.646030
# 1246    0.496040
# 1247    0.317589
# 1248    0.261591
# 1249    0.250096
#
# [1250 rows x 3 columns]
# KmeansCosineMinibatchSixProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1  genes closest to lead SNPs from Neale analysis...
# 3                  1  Genes closest to the lead SNPs from Ben Neale'...
# 4                  1  https://science.sciencemag.org/content/365/645...
# ...              ...                                                ...
# 4462               5                                       wild vs pale
# 4463               5  CD1 female mice adults - gestational CdCl2 vs ...
# 4464               5                                   Msc Role Disease
# 4465               5                                             ct1346
# 4466               5                Rheumatiod arthritis trasnscriptome
#
#       Odds_Ratio
# 0      46.729262
# 1       4.514899
# 2       7.136804
# 3      18.570492
# 4       3.455515
# ...          ...
# 4462    0.932856
# 4463    0.929785
# 4464    0.896765
# 4465    0.868038
# 4466    0.750350
#
# [4467 rows x 3 columns]
# KmedoidsCosineSixProposed
#       cluster_number                                            pathway  \
# 0                  3  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  3                                       inflammation
# 2                  3  10 percent of the longest transcripts of the h...
# 3                  3                                        Gdgtdrhyjgk
# 4                  3                 viral chromatin associated factors
# ...              ...                                                ...
# 4373               4                                      hola tomatito
# 4374               4                                         scc-cx HDE
# 4375               4                                      Endometriosis
# 4376               4                                        Sca1+ genes
# 4377               4                                              Rthth
#
#       Odds_Ratio
# 0      18.798968
# 1      20.805400
# 2       2.373728
# 3       3.032666
# 4       2.983293
# ...          ...
# 4373    0.405394
# 4374    0.389307
# 4375    0.383609
# 4376    0.351091
# 4377    0.311074
#
# [4378 rows x 3 columns]
# GMMZeroProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1  The genes about major depressive disorder anal...
# 4                  1  Genes closest to the lead SNPs from Ben Neale'...
# ...              ...                                                ...
# 2969               2                          pathway enrichment celiac
# 2970               2                    MEF-iPS diff ES DNA methylation
# 2971               2      Blue module gene list CRC (Normal and Cancer)
# 2972               2                                     pred all genes
# 2973               2  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      35.143114
# 1       3.664986
# 2       3.724960
# 3       6.309524
# 4      16.170752
# ...          ...
# 2969    0.369609
# 2970    0.341445
# 2971    0.322708
# 2972    0.559603
# 2973    0.247879
#
# [2974 rows x 3 columns]
# GMMOneProposed
#       cluster_number                                            pathway  \
# 0                  4  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  4                                       inflammation
# 2                  4  The genes about major depressive disorder anal...
# 3                  4  10 percent of the longest transcripts of the h...
# 4                  4         Genes that were expressed and up regulated
# ...              ...                                                ...
# 3993               3  Identification of the novel conserved transcri...
# 3994               3                   GSE140581 p65 LPS peaks from GEO
# 3995               3   HPV-cervical cancer up-regulated genes vs Normal
# 3996               3                                         DEG of ZZW
# 3997               3                                             ct1346
#
#       Odds_Ratio
# 0      23.706340
# 1      32.830438
# 2       5.839614
# 3       2.452579
# 4       3.101363
# ...          ...
# 3993    0.197001
# 3994    0.195250
# 3995    0.191726
# 3996    0.247554
# 3997    0.322396
#
# [3998 rows x 3 columns]
# BirchZeroProposed
#        cluster_number                                            pathway  \
# 0                   7                                   High in human RG
# 1                   7                                           PAH test
# 2                   7                                    Phosphopeptides
# 3                   7                                           Als Gene
# 4                   7                      Nextera rapid capture targets
# ...               ...                                                ...
# 18277               4                                   mir target genes
# 18278               4               TargetScanV7 135b target All targets
# 18279               4  Skin Cutaneous Melanoma under expressed genes ...
# 18280               4                          ARP1 WT vs E6 UTX binding
# 18281               4  shRNA knockdown of ARNT using TRC00003816 plas...
#
#        Odds_Ratio
# 0       87.477876
# 1       39.152610
# 2      120.854545
# 3       19.036072
# 4       19.036072
# ...           ...
# 18277    0.394295
# 18278    0.390312
# 18279    0.374177
# 18280    0.364616
# 18281    0.345682
#
# [18282 rows x 3 columns]
# BirchOneProposed
#       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                        Gdgtdrhyjgk
# 3                  0                                       inflammation
# 4                  0                                        brain pleio
# ...              ...                                                ...
# 2214               1                          pathway enrichment celiac
# 2215               1                    MEF-iPS diff ES DNA methylation
# 2216               1      Blue module gene list CRC (Normal and Cancer)
# 2217               1                                     pred all genes
# 2218               1  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      25.210486
# 1       2.951412
# 2       2.725184
# 3      13.129922
# 4       4.227302
# ...          ...
# 2214    0.369609
# 2215    0.341445
# 2216    0.322708
# 2217    0.559603
# 2218    0.247879
#
# [2219 rows x 3 columns]
# BirchTwoProposed
#       cluster_number                                            pathway  \
# 0                  0  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  0  10 percent of the longest transcripts of the h...
# 2                  0                                        Gdgtdrhyjgk
# 3                  0                                       inflammation
# 4                  0                                        brain pleio
# ...              ...                                                ...
# 2214               1                          pathway enrichment celiac
# 2215               1                    MEF-iPS diff ES DNA methylation
# 2216               1      Blue module gene list CRC (Normal and Cancer)
# 2217               1                                     pred all genes
# 2218               1  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      25.210486
# 1       2.951412
# 2       2.725184
# 3      13.129922
# 4       4.227302
# ...          ...
# 2214    0.369609
# 2215    0.341445
# 2216    0.322708
# 2217    0.559603
# 2218    0.247879
#
# [2219 rows x 3 columns]
# KmeansCosineTwoMinAICProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1                                       inflammation
# 4                  1                                        brain pleio
# ...              ...                                                ...
# 2214               0                          pathway enrichment celiac
# 2215               0                    MEF-iPS diff ES DNA methylation
# 2216               0      Blue module gene list CRC (Normal and Cancer)
# 2217               0                                     pred all genes
# 2218               0  Turquise module gene list CRC (Normal and Cancer)
#
#       Odds_Ratio
# 0      25.210486
# 1       2.951412
# 2       2.725184
# 3      13.129922
# 4       4.227302
# ...          ...
# 2214    0.369609
# 2215    0.341445
# 2216    0.322708
# 2217    0.559603
# 2218    0.247879
#
# [2219 rows x 3 columns]
# KmedoidsCosineThreeMinAICProposed
#       cluster_number                                            pathway  \
# 0                  1  lead SNPs from Neale v2 analysis of UKBB data,...
# 1                  1  10 percent of the longest transcripts of the h...
# 2                  1                                        Gdgtdrhyjgk
# 3                  1                                       inflammation
# 4                  1                                        brain pleio
# ...              ...                                                ...
# 2872               0                                Osteoclast specific
# 2873               0                              INTERACTOMIC ANALYSIS
# 2874               0                                         Mizosample
# 2875               0                                     kp vs wt 1.5fc
# 2876               0   HPV-cervical cancer up-regulated genes vs Normal
#
#       Odds_Ratio
# 0      25.210486
# 1       2.951412
# 2       2.725184
# 3      13.129922
# 4       4.227302
# ...          ...
# 2872    0.228486
# 2873    0.289612
# 2874    0.289612
# 2875    0.263283
# 2876    0.139858
#
# [2877 rows x 3 columns]

# %%
path_pca_tops_dict = {}
adj_score_lab = "adjusted_score"
for lab in pc_gene_groups_dict.keys():
    sorted_df = path_pca_OR_dict[lab].sort_values(by=OR_lab, ascending=False)
    df_wide = sorted_df.pivot_table(index='pathway', columns='bin', values=OR_lab)
    ind_list = df_wide.index
    col_list = df_wide.columns
    df_wide = pd.DataFrame(data = np.nan_to_num(df_wide),
                           index=ind_list,
                           columns = col_list)
    df_long= pd.melt(df_wide, ignore_index=False, value_name=OR_lab)
    df_long= df_long.reset_index()
    df_long_sorted = df_long.sort_values(by=OR_lab, ascending = False)
    top_fifty_byOR_df = df_long_sorted.head(50)
    top_five_perclust_df = df_long_sorted.groupby("bin").head(5)
    OR_dict = {top_five_lab:top_five_perclust_df, top_fifty_lab:top_fifty_byOR_df}
    sorted_df = path_pca_score_dict[lab].sort_values(by=score_lab, ascending=False)
    df_wide = sorted_df.pivot_table(index='pathway', columns='bin', values=score_lab)
    ind_list = df_wide.index
    col_list = df_wide.columns
    df_wide = pd.DataFrame(data = np.nan_to_num(df_wide),
                           index=ind_list,
                           columns = col_list)
    df_long= pd.melt(df_wide, ignore_index=False, value_name=score_lab)
    df_long= df_long.reset_index()
    df_long_sorted = df_long.sort_values(by=score_lab, ascending = False)
    top_fifty_byscore_df = df_long_sorted.head(50)
    top_five_perclust_df = df_long_sorted.groupby("bin").head(5)
    score_dict = {top_five_lab:top_five_perclust_df, top_fifty_lab:top_fifty_byscore_df}
    sorted_df = path_pca_adj_score_dict[lab].sort_values(by=adj_score_lab, ascending=False)
    df_wide = sorted_df.pivot_table(index='pathway', columns='bin', values=adj_score_lab)
    ind_list = df_wide.index
    col_list = df_wide.columns
    df_wide = pd.DataFrame(data = np.nan_to_num(df_wide),
                           index=ind_list,
                           columns = col_list)
    df_long= pd.melt(df_wide, ignore_index=False, value_name=adj_score_lab)
    df_long= df_long.reset_index()
    df_long_sorted = df_long.sort_values(by=adj_score_lab, ascending = False)
    top_fifty_byscore_df = df_long_sorted.head(50)
    top_five_perclust_df = df_long_sorted.groupby("bin").head(5)
    adj_score_dict = {top_five_lab:top_five_perclust_df, top_fifty_lab:top_fifty_byscore_df}
    path_pca_tops_dict[lab] = {OR_lab:OR_dict, score_lab:score_dict, adj_score_lab: adj_score_dict}
path_pca_tops_dict
# Out:
# {'pap': {'Odds_Ratio': {'top_five':                                                  pathway     bin    Odds_Ratio
#    13762                                wild and pearl mice  pc_2_0  31570.000000
#    13763                                       wild vs pale  pc_2_0  31546.000000
#    23909                            Basal 2 control Vs COPD  pc_2_9    203.551020
#    2672                                         CancerGenes  pc_1_2    201.808081
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8    159.752000
#    ...                                                  ...     ...           ...
#    18821  557gene litte list, dataset: c31f4fef2910f4f50...  pc_2_5     12.088415
#    19205  Inflammatory genes with most significant isofo...  pc_2_5     11.050195
#    20025                                            wodecuo  pc_2_5     10.988914
#    18155                  Ribavirin-Down Sars-Cov-2-S7-1-Up  pc_2_4     10.802832
#    17704             CircRNA in mouse developmental tissues  pc_2_4     10.557867
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin    Odds_Ratio
#    13762                                wild and pearl mice  pc_2_0  31570.000000
#    13763                                       wild vs pale  pc_2_0  31546.000000
#    23909                            Basal 2 control Vs COPD  pc_2_9    203.551020
#    2672                                         CancerGenes  pc_1_2    201.808081
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8    159.752000
#    22626                            Am Not Sure Ture Or Not  pc_2_8    153.600000
#    14342                PamGene significative kinases, CvsT  pc_2_1    138.708333
#    24848                                           lungdown  pc_2_9    110.594444
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8    105.206434
#    3086                           Predicted Cancer Gene Set  pc_1_2     90.763636
#    1293   557gene litte list, dataset: c31f4fef2910f4f50...  pc_1_1     90.759091
#    23630                            mouse aging anti genage  pc_2_8     88.662222
#    13218  TCGA EYA1 high related genes in BRCA, dataset:...  pc_2_0     83.737288
#    15862                                      child obesity  pc_2_2     83.200000
#    24256                                               Lung  pc_2_9     81.454918
#    14422                                       SCD survival  pc_2_1     77.996094
#    2834   Genes closest to the lead SNPs from Ben Neale'...  pc_1_2     76.676923
#    24633                                          clay dawn  pc_2_9     76.573674
#    14799                                       inflammation  pc_2_1     75.992381
#    22866  Genes closest to the lead SNPs from Ben Neale'...  pc_2_8     75.249057
#    1113                                      normalized Als  pc_1_0     73.933333
#    14918                       plts-Sil-tg only, common 1+4  pc_2_1     73.404412
#    14704                                         everolimus  pc_2_1     65.671053
#    15581  Ovarian cancer genes, dataset: 5041765f6f25416...  pc_2_2     62.757353
#    13772                       +E2, CtS +E2, si10 -E2, si10  pc_2_1     62.384375
#    16136                                     network of WAS  pc_2_2     62.384375
#    12804                                       For Compare4  pc_2_0     62.284810
#    14207                                            KHAZAYI  pc_2_1     61.829457
#    23345                                           b16 down  pc_2_8     61.320000
#    2090                                       child obesity  pc_1_1     60.490909
#    12643  Biogrid human PPI interaction cluterized using...  pc_2_0     59.054054
#    995         heat map Clust3 genes up with ROSI treatment  pc_1_0     57.011429
#    21996                           TNBC vs HCC Common genes  pc_2_7     54.972452
#    21511  Depending on gender, these genes can have vary...  pc_2_7     54.972452
#    15910                      dentate gyrus gene expression  pc_2_2     54.239130
#    13567  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_0     52.186170
#    12566                                8A-WAvsWW upChart-3  pc_2_0     51.765172
#    24782   heart, dataset: 299bdebd46d940223ab8ad8b6e3afa0f  pc_2_9     50.832232
#    15851                                cad&sleep gene list  pc_2_2     49.895000
#    24654                                          cove dawn  pc_2_9     49.143223
#    14853                    miRNA-regulated in CD4+ T cells  pc_2_1     47.973558
#    5962                 gene set of breast cancer colombian  pc_1_4     46.610526
#    13276         Up in vitamin C in endothelial cells human  pc_2_0     44.553531
#    14965  si4 attached+si4 spheres vs siCNTR attached +s...  pc_2_1     43.004310
#    14779                                      hsa-let-7f-5p  pc_2_1     42.840860
#    3177                                       Schizophrenia  pc_1_2     42.167019
#    22855         Gene set of Glycolysis and TCA cycle genes  pc_2_8     41.892632
#    15966                  follicular lymphoma mutated genes  pc_2_2     41.568750
#    15079        ADAD vs control exitarory cells upregulater  pc_2_2     40.225806
#    3569   mRNAs Blancos de hsa-miR-100-5p predichos por ...  pc_1_2     39.411067},
#   'combined_score': {'top_five':                                                  pathway     bin  \
#    13762                                wild and pearl mice  pc_2_0
#    13763                                       wild vs pale  pc_2_0
#    18575  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_4
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    ...                                                  ...     ...
#    18254  The genes about major depressive disorder anal...  pc_2_4
#    16339                                  ALX1 target genes  pc_2_3
#    19205  Inflammatory genes with most significant isofo...  pc_2_5
#    19091                                        Gdgtdrhyjgk  pc_2_5
#    19104                  Genes Involved In Prostate Cancer  pc_2_5
#
#           combined_score
#    13762    98320.258821
#    13763    98066.126316
#    18575     2754.675440
#    9811      1549.385299
#    23583     1391.116257
#    ...               ...
#    18254       47.588304
#    16339       46.472760
#    19205       45.303269
#    19091       40.485233
#    19104       39.977327
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    13762                                wild and pearl mice  pc_2_0
#    13763                                       wild vs pale  pc_2_0
#    18575  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_4
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    4803   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_3
#    2672                                         CancerGenes  pc_1_2
#    23909                            Basal 2 control Vs COPD  pc_2_9
#    6055   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_4
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8
#    17323  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_3
#    22626                            Am Not Sure Ture Or Not  pc_2_8
#    14342                PamGene significative kinases, CvsT  pc_2_1
#    15581  Ovarian cancer genes, dataset: 5041765f6f25416...  pc_2_2
#    2834   Genes closest to the lead SNPs from Ben Neale'...  pc_1_2
#    14799                                       inflammation  pc_2_1
#    7307   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_5
#    2299   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_1
#    24633                                          clay dawn  pc_2_9
#    24848                                           lungdown  pc_2_9
#    14207                                            KHAZAYI  pc_2_1
#    3086                           Predicted Cancer Gene Set  pc_1_2
#    1293   557gene litte list, dataset: c31f4fef2910f4f50...  pc_1_1
#    23630                            mouse aging anti genage  pc_2_8
#    15862                                      child obesity  pc_2_2
#    14422                                       SCD survival  pc_2_1
#    24256                                               Lung  pc_2_9
#    5962                 gene set of breast cancer colombian  pc_1_4
#    13218  TCGA EYA1 high related genes in BRCA, dataset:...  pc_2_0
#    22866  Genes closest to the lead SNPs from Ben Neale'...  pc_2_8
#    1113                                      normalized Als  pc_1_0
#    14918                       plts-Sil-tg only, common 1+4  pc_2_1
#    1047   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_0
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    14779                                      hsa-let-7f-5p  pc_2_1
#    24782   heart, dataset: 299bdebd46d940223ab8ad8b6e3afa0f  pc_2_9
#    14704                                         everolimus  pc_2_1
#    24654                                          cove dawn  pc_2_9
#    3551   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_2
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    18366                                      child obesity  pc_2_4
#    13772                       +E2, CtS +E2, si10 -E2, si10  pc_2_1
#    16136                                     network of WAS  pc_2_2
#    16071  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_2
#    14891                                     oct2Open peaks  pc_2_1
#    2090                                       child obesity  pc_1_1
#    23345                                           b16 down  pc_2_8
#
#           combined_score
#    13762    98320.258821
#    13763    98066.126316
#    18575     2754.675440
#    9811      1549.385299
#    23583     1391.116257
#    8559      1256.503023
#    21079     1249.096139
#    19827     1178.673349
#    4803      1043.932090
#    2672      1032.951295
#    23909      996.446358
#    6055       921.656680
#    22864      775.878398
#    17323      740.603517
#    22626      740.221819
#    14342      661.819014
#    15581      657.616217
#    2834       588.522912
#    14799      586.460626
#    7307       585.834724
#    2299       538.142108
#    24633      478.942718
#    24848      475.393363
#    14207      452.897086
#    3086       397.505318
#    1293       397.125975
#    23630      380.247469
#    15862      358.067161
#    14422      330.973809
#    24256      325.722363
#    5962       316.243197
#    13218      313.864514
#    22866      310.731701
#    1113       309.051915
#    14918      307.322787
#    1047       306.723375
#    11063      297.994722
#    14779      283.746193
#    24782      278.113419
#    14704      268.078772
#    24654      265.727264
#    3551       258.101726
#    22331      254.235607
#    18366      253.539705
#    13772      251.643234
#    16136      251.643234
#    16071      249.071882
#    14891      246.914768
#    2090       242.184823
#    23345      241.000152  },
#   'adjusted_score': {'top_five':                                                  pathway     bin  \
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    23909                            Basal 2 control Vs COPD  pc_2_9
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8
#    22626                            Am Not Sure Ture Or Not  pc_2_8
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    ...                                                  ...     ...
#    2268                                 hubs gene alzahimer  pc_1_1
#    2248                                heat shock for tumor  pc_1_1
#    2249                                          hela cells  pc_1_1
#    2250                                           hgfdxgfgh  pc_1_1
#    2251                      highly potent targetable genes  pc_1_1
#
#           adjusted_score
#    23583    10653.863857
#    23909     9744.747156
#    22864     5942.064712
#    22626     5668.988802
#    9811      5401.157154
#    ...               ...
#    2268         0.000000
#    2248         0.000000
#    2249         0.000000
#    2250         0.000000
#    2251         0.000000
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    23909                            Basal 2 control Vs COPD  pc_2_9
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8
#    22626                            Am Not Sure Ture Or Not  pc_2_8
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    24633                                          clay dawn  pc_2_9
#    24848                                           lungdown  pc_2_9
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    24256                                               Lung  pc_2_9
#    23630                            mouse aging anti genage  pc_2_8
#    24782   heart, dataset: 299bdebd46d940223ab8ad8b6e3afa0f  pc_2_9
#    24654                                          cove dawn  pc_2_9
#    22866  Genes closest to the lead SNPs from Ben Neale'...  pc_2_8
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    23345                                           b16 down  pc_2_8
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    11994  The genes about major depressive disorder anal...  pc_1_9
#    24696  downregulated, dataset: 6d5ee3258f0d93c3f9f758...  pc_2_9
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    24889                       mouse cells, KO target genes  pc_2_9
#    21996                           TNBC vs HCC Common genes  pc_2_7
#    21511  Depending on gender, these genes can have vary...  pc_2_7
#    24647      common genes from iCLIP and RNA-seq data sets  pc_2_9
#    22855         Gene set of Glycolysis and TCA cycle genes  pc_2_8
#    24103               Gene expression between wt and ube3a  pc_2_9
#    23510                                     h3k27 promoter  pc_2_8
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    24591                                          arch dawn  pc_2_9
#    23425                                    diabetes type 1  pc_2_8
#    23172                                      SALL4 related  pc_2_8
#    22950                                 IDH DOWNREGULATION  pc_2_8
#    24209       Identified by the KroganLab in 2020 (nature)  pc_2_9
#    22675      CA1-TRAP vs BG TRAP RNAseq upregulated in CA1  pc_2_8
#    11392  Biological insights from 108 schizophrenia-ass...  pc_1_9
#    23687                              pre susceptible genes  pc_2_8
#    24902  novel genes and significant in both sift and p...  pc_2_9
#    12363                           mouse aging anti gomperz  pc_1_9
#    23486                         genage all bedoone tekrari  pc_2_8
#    11968                                        TF OF H3.2C  pc_1_9
#    24619                        capan1 downregulated p<0.05  pc_2_9
#    10340                  Genes Involved In Prostate Cancer  pc_1_8
#    9602                                       child obesity  pc_1_7
#    22486                                 spinal cord injury  pc_2_7
#    23545                                     hsa-miR-33a-5p  pc_2_8
#    23055                                             Muscle  pc_2_8
#    22876                                   Genes in MDK sig  pc_2_8
#    24238                             LIN28 shRNA microarray  pc_2_9
#    11577                                      GWAS AD GENES  pc_1_9
#    21284                       +E2, CtS +E2, si10 -E2, si10  pc_2_7
#
#           adjusted_score
#    23583    10653.863857
#    23909     9744.747156
#    22864     5942.064712
#    22626     5668.988802
#    9811      5401.157154
#    24633     4683.820306
#    24848     4649.109394
#    21079     4268.786054
#    24256     3185.401848
#    23630     2912.125244
#    24782     2719.810186
#    24654     2598.679774
#    22866     2379.738734
#    8559      1954.490452
#    23345     1845.699666
#    11063     1614.088413
#    19827     1528.149997
#    11994     1504.321180
#    24696     1475.225786
#    22331     1407.956792
#    24889     1245.247555
#    21996     1187.700600
#    21511     1187.700600
#    24647     1160.374247
#    22855     1141.933502
#    24103     1100.344040
#    23510     1088.905715
#    12315     1074.635213
#    24591     1017.349542
#    23425      980.150738
#    23172      903.101141
#    22950      892.943712
#    24209      876.304909
#    22675      856.487436
#    11392      845.635593
#    23687      809.693833
#    24902      806.696070
#    12363      786.567206
#    23486      731.704215
#    11968      720.329197
#    24619      706.956102
#    10340      697.527666
#    9602       694.071264
#    22486      689.404758
#    23545      665.734352
#    23055      653.738137
#    22876      642.114516
#    24238      596.923596
#    11577      574.694516
#    21284      560.519016  }},
#  'ours': {'Odds_Ratio': {'top_five':                                                  pathway     bin  Odds_Ratio
#    5235   Depending on gender, these genes can have vary...  pc_1_4  227.045455
#    11838                PamGene significative kinases, CvsT  pc_1_9  130.542484
#    5237                      Diabetic retinopathy Metformin  pc_1_4   83.170833
#    12641                            Basal 2 control Vs COPD  pc_2_0   81.408163
#    6588   Genes associated with osteonecrosis in ALL chi...  pc_1_5   79.856000
#    ...                                                  ...     ...         ...
#    18575  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_4   14.244772
#    9342   Phosphoproteomics platelets Perseus ttest: P<0...  pc_1_7   13.899301
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8   13.727779
#    10311                                           GES21520  pc_1_8   13.241333
#    9859                            mouse aging anti gomperz  pc_1_7   12.905844
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  Odds_Ratio
#    5235   Depending on gender, these genes can have vary...  pc_1_4  227.045455
#    11838                PamGene significative kinases, CvsT  pc_1_9  130.542484
#    5237                      Diabetic retinopathy Metformin  pc_1_4   83.170833
#    12641                            Basal 2 control Vs COPD  pc_2_0   81.408163
#    6588   Genes associated with osteonecrosis in ALL chi...  pc_1_5   79.856000
#    12471                           spinal cord injury model  pc_1_9   78.301961
#    11598  Genes closest to the lead SNPs from Ben Neale'...  pc_1_9   78.160784
#    6350                             Am Not Sure Ture Or Not  pc_1_5   76.780769
#    12470                                 spinal cord injury  pc_1_9   69.083045
#    12890         HMGB1-interacted proteins pathway analysis  pc_2_0   67.576271
#    12200                                         everolimus  pc_1_9   61.804954
#    5854     closest cardiac imaging genes Pirruccello et al  pc_1_4   59.372024
#    11268                       +E2, CtS +E2, si10 -E2, si10  pc_1_9   58.711765
#    4594                                       child obesity  pc_1_3   58.119534
#    5117          BIOID mass spec resuts of M4K4 interactors  pc_1_4   57.988372
#    14867                           mouse aging anti gomperz  pc_2_1   57.028571
#    6102                             mouse aging anti genage  pc_1_4   55.405556
#    14431                                     SLE risk genes  pc_2_1   53.610215
#    5897                                     diabetes type 1  pc_1_4   53.598383
#    14390  Rat proximal tubule TF network identified by wTO.  pc_2_1   51.932292
#    23964             CircRNA in mouse developmental tissues  pc_2_9   51.105128
#    5413          Human TREM2- CTRL vs TREM2+ CTRL TOP 50 UP  pc_1_4   50.872449
#    15192                                        CancerGenes  pc_2_2   50.368687
#    5048                                      54DNs 1 YapTaz  pc_1_4   49.852500
#    13133  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_0   47.978313
#    12095                                cad&sleep gene list  pc_1_9   46.957647
#    23268  Top 10 DEG genes between benign and malign pro...  pc_2_8   45.217687
#    12349                    miRNA-regulated in CD4+ T cells  pc_1_9   45.149321
#    7354                             mouse aging anti genage  pc_1_5   44.320000
#    13104                           Prlr +/- from beta cells  pc_2_0   42.340426
#    6055   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_4   42.076139
#    6381                             Basal 2 control Vs COPD  pc_1_5   40.693878
#    12461  si4 attached+si4 spheres vs siCNTR attached +s...  pc_1_9   40.472617
#    13824                                      AD candidates  pc_2_1   39.908000
#    5320                          Gene List Hot Spot Project  pc_1_4   39.378968
#    2299   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_1   38.642282
#    7839   Genes associated with T1D from the genomics co...  pc_1_6   37.770833
#    8139                   Ribavirin-Down Sars-Cov-2-S7-1-Up  pc_1_6   37.770833
#    5923   e15 limb chirp seq lncRNA top 90 percent coinc...  pc_1_4   37.736742
#    13409                                    diabetes type 1  pc_2_0   37.171963
#    13379      common genes from iCLIP and RNA-seq data sets  pc_2_0   36.941948
#    11298  34 genes associated with Chronic Pain from Tab...  pc_1_9   35.559715
#    12864                                       Genes of IMF  pc_2_0   33.977778
#    6630          HMGB1-interacted proteins pathway analysis  pc_1_5   33.779661
#    12263       heat map Clust3 genes up with ROSI treatment  pc_1_9   33.524370
#    2030                                           XP8GY-12H  pc_1_1   33.215000
#    6404                                       CD161-/CD161+  pc_1_5   32.668852
#    687                   Sofosbuvir-Down Sars-Cov-2-S7-1-Up  pc_1_0   32.575163
#    17114                                      child obesity  pc_2_3   32.298701
#    14100  Genes associated with osteonecrosis in ALL chi...  pc_2_1   31.918400},
#   'combined_score': {'top_five':                                                  pathway     bin  \
#    2299   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_1
#    17323  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_3
#    5235   Depending on gender, these genes can have vary...  pc_1_4
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    16071  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_2
#    ...                                                  ...     ...
#    10905                                    diabetes type 1  pc_1_8
#    18540  https://science.sciencemag.org/content/365/645...  pc_2_4
#    10748  Top 10 DEG genes between benign and malign pro...  pc_1_8
#    18268                                  Two different KOs  pc_2_4
#    24011                                     Darkblue(High)  pc_2_9
#
#           combined_score
#    2299      2383.501000
#    17323     1687.179235
#    5235      1185.987693
#    19827     1115.516683
#    16071     1112.774712
#    ...               ...
#    10905       58.731468
#    18540       52.974091
#    10748       49.312541
#    18268       46.097000
#    24011       45.945026
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    2299   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_1
#    17323  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_3
#    5235   Depending on gender, these genes can have vary...  pc_1_4
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    16071  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_2
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    3551   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_2
#    11598  Genes closest to the lead SNPs from Ben Neale'...  pc_1_9
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    11838                PamGene significative kinases, CvsT  pc_1_9
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    18575  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_4
#    4803   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_3
#    6055   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_4
#    4594                                       child obesity  pc_1_3
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    14431                                     SLE risk genes  pc_2_1
#    5897                                     diabetes type 1  pc_1_4
#    14390  Rat proximal tubule TF network identified by wTO.  pc_2_1
#    1047   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_0
#    5237                      Diabetic retinopathy Metformin  pc_1_4
#    23964             CircRNA in mouse developmental tissues  pc_2_9
#    12641                            Basal 2 control Vs COPD  pc_2_0
#    6588   Genes associated with osteonecrosis in ALL chi...  pc_1_5
#    12471                           spinal cord injury model  pc_1_9
#    6350                             Am Not Sure Ture Or Not  pc_1_5
#    12470                                 spinal cord injury  pc_1_9
#    12890         HMGB1-interacted proteins pathway analysis  pc_2_0
#    12200                                         everolimus  pc_1_9
#    5320                          Gene List Hot Spot Project  pc_1_4
#    22242  genes closest to lead SNPs from Neale analysis...  pc_2_7
#    5854     closest cardiac imaging genes Pirruccello et al  pc_1_4
#    11268                       +E2, CtS +E2, si10 -E2, si10  pc_1_9
#    5117          BIOID mass spec resuts of M4K4 interactors  pc_1_4
#    16339                                  ALX1 target genes  pc_2_3
#    14867                           mouse aging anti gomperz  pc_2_1
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    13379      common genes from iCLIP and RNA-seq data sets  pc_2_0
#    6102                             mouse aging anti genage  pc_1_4
#    17114                                      child obesity  pc_2_3
#    5413          Human TREM2- CTRL vs TREM2+ CTRL TOP 50 UP  pc_1_4
#    15192                                        CancerGenes  pc_2_2
#    5048                                      54DNs 1 YapTaz  pc_1_4
#    14819  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_1
#    63                                     ALX1 target genes  pc_1_0
#    14064                                        GE-K9-4-bed  pc_2_1
#    6779                                              Muscle  pc_1_5
#    13133  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_0
#
#           combined_score
#    2299      2383.501000
#    17323     1687.179235
#    5235      1185.987693
#    19827     1115.516683
#    16071     1112.774712
#    21079     1112.760229
#    9811      1008.030640
#    3551       970.661202
#    11598      869.471496
#    8559       744.082054
#    22331      715.949354
#    11838      615.425022
#    11063      569.115377
#    18575      533.155575
#    4803       471.036572
#    6055       468.707158
#    4594       418.371875
#    23583      388.904326
#    14431      379.864290
#    5897       369.465372
#    14390      364.868168
#    1047       361.426390
#    5237       355.828339
#    23964      355.743323
#    12641      342.389562
#    6588       339.687615
#    12471      332.541203
#    6350       323.727778
#    12470      285.311114
#    12890      271.978647
#    12200      248.793415
#    5320       247.958031
#    22242      235.786413
#    5854       234.725283
#    11268      233.502245
#    5117       227.933516
#    16339      225.776110
#    14867      225.039974
#    12315      223.617983
#    13379      219.763896
#    6102       215.340551
#    17114      196.119266
#    5413       193.520870
#    15192      191.609531
#    5048       188.663684
#    14819      187.676075
#    63         184.884133
#    14064      182.768292
#    6779       178.491985
#    13133      177.101900  },
#   'adjusted_score': {'top_five':                                                  pathway     bin  \
#    11598  Genes closest to the lead SNPs from Ben Neale'...  pc_1_9
#    11838                PamGene significative kinases, CvsT  pc_1_9
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    12471                           spinal cord injury model  pc_1_9
#    ...                                                  ...     ...
#    3429                                   endothelial cells  pc_1_2
#    3631                                         p53 targets  pc_1_2
#    3532                                        injured treg  pc_1_2
#    3535                                         interesting  pc_1_2
#    3537                                           just down  pc_1_2
#
#           adjusted_score
#    11598    11483.544778
#    11838     8128.225981
#    9811      7404.993081
#    11063     5848.514176
#    12471     4392.037941
#    ...               ...
#    3429         0.000000
#    3631         0.000000
#    3532         0.000000
#    3535         0.000000
#    3537         0.000000
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    11598  Genes closest to the lead SNPs from Ben Neale'...  pc_1_9
#    11838                PamGene significative kinases, CvsT  pc_1_9
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    12471                           spinal cord injury model  pc_1_9
#    12470                                 spinal cord injury  pc_1_9
#    12200                                         everolimus  pc_1_9
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    11268                       +E2, CtS +E2, si10 -E2, si10  pc_1_9
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    23964             CircRNA in mouse developmental tissues  pc_2_9
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    12095                                cad&sleep gene list  pc_1_9
#    12349                    miRNA-regulated in CD4+ T cells  pc_1_9
#    12461  si4 attached+si4 spheres vs siCNTR attached +s...  pc_1_9
#    11298  34 genes associated with Chronic Pain from Tab...  pc_1_9
#    12263       heat map Clust3 genes up with ROSI treatment  pc_1_9
#    10580                                     PCa signatures  pc_1_8
#    11640                                         HO36 group  pc_1_9
#    11847                                       Pi Gene list  pc_1_9
#    10179                                         Cac vs. WT  pc_1_8
#    23268  Top 10 DEG genes between benign and malign pro...  pc_2_8
#    22242  genes closest to lead SNPs from Neale analysis...  pc_2_7
#    12083                     bladder cancer, dataset: 7w0x7  pc_1_9
#    11973                         THP-MVs Sil CvsCL down-sig  pc_1_9
#    12460                          shortened in laminB1 over  pc_1_9
#    12485                              triple dominant group  pc_1_9
#    12316                            lengthened laminB1 over  pc_1_9
#    9569                   autism confidence gene from SFARI  pc_1_7
#    12239                                     gfp as control  pc_1_9
#    23897         BIOID mass spec resuts of M4K4 interactors  pc_2_9
#    11638         HMGB1-interacted proteins pathway analysis  pc_1_9
#    9776   https://science.sciencemag.org/content/365/645...  pc_1_7
#    12275                                      hsa-let-7f-5p  pc_1_9
#    11773                                          Microarry  pc_1_9
#    11272  10 percent of the longest transcripts of the h...  pc_1_9
#    9584                                         brain pleio  pc_1_7
#    10905                                    diabetes type 1  pc_1_8
#    24118  Genes closest to the lead SNPs from Ben Neale'...  pc_2_9
#    22983                                     LFQ-upCtrl 1.5  pc_2_8
#    11698            Intersection Among Different Timepoints  pc_1_9
#    8139                   Ribavirin-Down Sars-Cov-2-S7-1-Up  pc_1_6
#    7839   Genes associated with T1D from the genomics co...  pc_1_6
#    23700                                      ptx2 pulldown  pc_2_8
#    12156                                        depresssion  pc_1_9
#    12413                      plts-Sil-WTonly Common in 2+3  pc_1_9
#    23374                                      child obesity  pc_2_8
#    23739                           spinal cord injury model  pc_2_8
#
#           adjusted_score
#    11598    11483.544778
#    11838     8128.225981
#    9811      7404.993081
#    11063     5848.514176
#    12471     4392.037941
#    12470     3768.246535
#    12200     3285.939025
#    8559      3285.494307
#    11268     3083.980900
#    22331     3039.920956
#    12315     2953.434504
#    23964     2906.778690
#    21079     2541.544362
#    23583     2414.512507
#    12095     2335.424208
#    12349     2223.235490
#    12461     1937.305872
#    11298     1644.151922
#    12263     1525.111766
#    10580     1403.407993
#    11640     1284.584725
#    11847     1269.157851
#    10179     1048.714219
#    23268     1038.688334
#    22242     1001.149111
#    12083      960.867594
#    11973      936.212423
#    12460      890.014995
#    12485      888.198049
#    12316      808.444006
#    9569       796.254526
#    12239      790.015973
#    23897      782.265999
#    11638      772.288423
#    9776       733.913562
#    12275      707.670704
#    11773      645.207967
#    11272      622.132303
#    9584       609.717166
#    10905      603.553934
#    24118      595.786656
#    22983      595.505140
#    11698      591.480426
#    8139       591.235830
#    7839       591.235830
#    23700      565.069723
#    12156      559.946034
#    12413      559.691523
#    23374      545.114590
#    23739      545.114590  }},
#  'ours_with_exp': {'Odds_Ratio': {'top_five':                                                  pathway     bin  Odds_Ratio
#    6487   Depending on gender, these genes can have vary...  pc_1_5  227.045455
#    570                  PamGene significative kinases, CvsT  pc_1_0   96.458937
#    5336   Genes associated with osteonecrosis in ALL chi...  pc_1_4   88.733333
#    5098                             Am Not Sure Ture Or Not  pc_1_4   85.316239
#    6489                      Diabetic retinopathy Metformin  pc_1_5   83.170833
#    ...                                                  ...     ...         ...
#    3131                   Ribavirin-Down Sars-Cov-2-S7-1-Up  pc_1_2   14.275144
#    19778                                          hgfdxgfgh  pc_2_5   14.027523
#    1547                                            GES21520  pc_1_1   13.796528
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5   13.757042
#    3082   Phosphoproteomics platelets Perseus ttest: P<0...  pc_1_2   13.176393
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  Odds_Ratio
#    6487   Depending on gender, these genes can have vary...  pc_1_5  227.045455
#    570                  PamGene significative kinases, CvsT  pc_1_0   96.458937
#    5336   Genes associated with osteonecrosis in ALL chi...  pc_1_4   88.733333
#    5098                             Am Not Sure Ture Or Not  pc_1_4   85.316239
#    6489                      Diabetic retinopathy Metformin  pc_1_5   83.170833
#    23909                            Basal 2 control Vs COPD  pc_2_9   81.408163
#    24158         HMGB1-interacted proteins pathway analysis  pc_2_9   67.576271
#    8350                                       child obesity  pc_1_6   63.298413
#    7106     closest cardiac imaging genes Pirruccello et al  pc_1_5   59.372024
#    6369          BIOID mass spec resuts of M4K4 interactors  pc_1_5   57.988372
#    1203                            spinal cord injury model  pc_1_0   57.857971
#    23631                           mouse aging anti gomperz  pc_2_8   57.028571
#    330    Genes closest to the lead SNPs from Ben Neale'...  pc_1_0   55.812325
#    7354                             mouse aging anti genage  pc_1_5   55.405556
#    23195                                     SLE risk genes  pc_2_8   53.610215
#    7149                                     diabetes type 1  pc_1_5   53.598383
#    23154  Rat proximal tubule TF network identified by wTO.  pc_2_8   51.932292
#    12696             CircRNA in mouse developmental tissues  pc_2_0   51.105128
#    1202                                  spinal cord injury  pc_1_0   51.046036
#    6665          Human TREM2- CTRL vs TREM2+ CTRL TOP 50 UP  pc_1_5   50.872449
#    6300                                      54DNs 1 YapTaz  pc_1_5   49.852500
#    6102                             mouse aging anti genage  pc_1_4   49.246914
#    21452                                        CancerGenes  pc_2_7   49.246914
#    24401  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_9   47.978313
#    932                                           everolimus  pc_1_0   45.668192
#    5129                             Basal 2 control Vs COPD  pc_1_4   45.217687
#    14504  Top 10 DEG genes between benign and malign pro...  pc_2_1   45.217687
#    4083   Genes associated with T1D from the genomics co...  pc_1_3   43.747807
#    0                           +E2, CtS +E2, si10 -E2, si10  pc_1_0   43.382609
#    24372                           Prlr +/- from beta cells  pc_2_9   42.340426
#    7307   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_5   42.076139
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8   41.972143
#    22588                                      AD candidates  pc_2_8   39.908000
#    6572                          Gene List Hot Spot Project  pc_1_5   39.378968
#    7175   e15 limb chirp seq lncRNA top 90 percent coinc...  pc_1_5   37.736742
#    5378          HMGB1-interacted proteins pathway analysis  pc_1_4   37.534840
#    24677                                    diabetes type 1  pc_2_9   37.171963
#    24647      common genes from iCLIP and RNA-seq data sets  pc_2_9   36.941948
#    4594                                       child obesity  pc_1_3   34.992982
#    827                                  cad&sleep gene list  pc_1_0   34.697391
#    5527                                              Muscle  pc_1_4   34.215517
#    24132                                       Genes of IMF  pc_2_9   33.977778
#    20870                                      child obesity  pc_2_6   33.843537
#    1081                     miRNA-regulated in CD4+ T cells  pc_1_0   33.361204
#    11955                 Sofosbuvir-Down Sars-Cov-2-S7-1-Up  pc_1_9   32.575163
#    10794                                          XP8GY-12H  pc_1_8   32.140323
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8   31.918400
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7   31.905939
#    6758                                            Mayocyte  pc_1_5   30.725309
#    11331                                  ALX1 target genes  pc_1_9   30.649231},
#   'combined_score': {'top_five':                                                  pathway     bin  \
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    17323  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_3
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    6487   Depending on gender, these genes can have vary...  pc_1_5
#    ...                                                  ...     ...
#    1984   Top 10 DEG genes between benign and malign pro...  pc_1_1
#    19792  https://science.sciencemag.org/content/365/645...  pc_2_5
#    12743                                     Darkblue(High)  pc_2_0
#    19520                                  Two different KOs  pc_2_5
#    3630              p1 top200 marker genes, dataset: 5py8m  pc_1_2
#
#           combined_score
#    11063     2855.934408
#    21079     1659.493161
#    17323     1299.498324
#    22331     1281.928606
#    6487      1185.987693
#    ...               ...
#    1984        52.104532
#    19792       49.412289
#    12743       45.945026
#    19520       44.245257
#    3630        41.865275
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    17323  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_3
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    6487   Depending on gender, these genes can have vary...  pc_1_5
#    3551   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_2
#    18575  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_4
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    4803   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_3
#    2299   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_1
#    16071  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_2
#    330    Genes closest to the lead SNPs from Ben Neale'...  pc_1_0
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    7307   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_5
#    8350                                       child obesity  pc_1_6
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    570                  PamGene significative kinases, CvsT  pc_1_0
#    14819  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_1
#    5336   Genes associated with osteonecrosis in ALL chi...  pc_1_4
#    23195                                     SLE risk genes  pc_2_8
#    7149                                     diabetes type 1  pc_1_5
#    5098                             Am Not Sure Ture Or Not  pc_1_4
#    23154  Rat proximal tubule TF network identified by wTO.  pc_2_8
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    6489                      Diabetic retinopathy Metformin  pc_1_5
#    12696             CircRNA in mouse developmental tissues  pc_2_0
#    23909                            Basal 2 control Vs COPD  pc_2_9
#    24158         HMGB1-interacted proteins pathway analysis  pc_2_9
#    6572                          Gene List Hot Spot Project  pc_1_5
#    20095                                  ALX1 target genes  pc_2_6
#    7106     closest cardiac imaging genes Pirruccello et al  pc_1_5
#    1203                            spinal cord injury model  pc_1_0
#    6369          BIOID mass spec resuts of M4K4 interactors  pc_1_5
#    23631                           mouse aging anti gomperz  pc_2_8
#    24647      common genes from iCLIP and RNA-seq data sets  pc_2_9
#    1047   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_0
#    7354                             mouse aging anti genage  pc_1_5
#    20870                                      child obesity  pc_2_6
#    5527                                              Muscle  pc_1_4
#    1202                                  spinal cord injury  pc_1_0
#    6665          Human TREM2- CTRL vs TREM2+ CTRL TOP 50 UP  pc_1_5
#    6300                                      54DNs 1 YapTaz  pc_1_5
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    21452                                        CancerGenes  pc_2_7
#    6102                             mouse aging anti genage  pc_1_4
#    11331                                  ALX1 target genes  pc_1_9
#    22828                                        GE-K9-4-bed  pc_2_8
#    24401  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_9
#    15982  genes closest to lead SNPs from Neale analysis...  pc_2_2
#    932                                           everolimus  pc_1_0
#
#           combined_score
#    11063     2855.934408
#    21079     1659.493161
#    17323     1299.498324
#    22331     1281.928606
#    6487      1185.987693
#    3551      1119.191860
#    18575     1089.789244
#    9811       838.272542
#    4803       625.174035
#    2299       613.940419
#    16071      596.076121
#    330        570.802923
#    19827      506.303941
#    7307       468.707158
#    8350       465.981899
#    8559       436.878970
#    570        427.123227
#    14819      388.904326
#    5336       385.851421
#    23195      379.864290
#    7149       369.465372
#    5098       367.791702
#    23154      364.868168
#    12315      361.426390
#    6489       355.828339
#    12696      355.743323
#    23909      342.389562
#    24158      271.978647
#    6572       247.958031
#    20095      240.564118
#    7106       234.725283
#    1203       229.202680
#    6369       227.933516
#    23631      225.039974
#    24647      219.763896
#    1047       217.444235
#    7354       215.340551
#    20870      208.531429
#    5527       207.514658
#    1202       196.263596
#    6665       193.520870
#    6300       188.663684
#    23583      187.676075
#    21452      186.270813
#    6102       186.270813
#    11331      184.884133
#    22828      182.768292
#    24401      177.101900
#    15982      173.644394
#    932        170.827423  },
#   'adjusted_score': {'top_five':                                                  pathway     bin  \
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    ...                                                  ...     ...
#    6053                                       laminB1 over3  pc_1_4
#    382                               Hashimoto, 1.2 fold up  pc_1_0
#    381                                    Harvard home work  pc_1_0
#    380        HYDROXYCHLOROQUINE-UP SARS-COV-2-UP-Cluster-1  pc_1_0
#    379             HYDROXYCHLOROQUINE-UP SARS-COV-2-S7-1-UP  pc_1_0
#
#           adjusted_score
#    11063    29196.217453
#    22331     7185.850801
#    9811      6120.227832
#    21079     6021.470935
#    12315     4750.949892
#    ...               ...
#    6053         0.000000
#    382          0.000000
#    381          0.000000
#    380          0.000000
#    379          0.000000
#
#    [100 rows x 3 columns],
#    'top_fifty':                                                  pathway     bin  \
#    11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
#    22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
#    9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
#    21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
#    12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
#    23909                            Basal 2 control Vs COPD  pc_2_9
#    23195                                     SLE risk genes  pc_2_8
#    23154  Rat proximal tubule TF network identified by wTO.  pc_2_8
#    24158         HMGB1-interacted proteins pathway analysis  pc_2_9
#    11331                                  ALX1 target genes  pc_1_9
#    24647      common genes from iCLIP and RNA-seq data sets  pc_2_9
#    8350                                       child obesity  pc_1_6
#    11927                                     SLE risk genes  pc_1_9
#    8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
#    6487   Depending on gender, these genes can have vary...  pc_1_5
#    23631                           mouse aging anti gomperz  pc_2_8
#    24401  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_9
#    12295                                       inflammation  pc_1_9
#    24209       Identified by the KroganLab in 2020 (nature)  pc_2_9
#    11955                 Sofosbuvir-Down Sars-Cov-2-S7-1-Up  pc_1_9
#    24372                           Prlr +/- from beta cells  pc_2_9
#    23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
#    22828                                        GE-K9-4-bed  pc_2_8
#    24619                        capan1 downregulated p<0.05  pc_2_9
#    11703                                            KHAZAYI  pc_1_9
#    24677                                    diabetes type 1  pc_2_9
#    24501  TNBC vs Normal Differential Gene Expression An...  pc_2_9
#    10794                                          XP8GY-12H  pc_1_8
#    12106                                      child obesity  pc_1_9
#    22588                                      AD candidates  pc_2_8
#    24132                                       Genes of IMF  pc_2_9
#    24544         Up in vitamin C in endothelial cells human  pc_2_9
#    11051                                   kc exo mass spec  pc_1_8
#    22660  Biological insights from 108 schizophrenia-ass...  pc_2_8
#    21452                                        CancerGenes  pc_2_7
#    11918                                       SCD survival  pc_1_9
#    10020  10 percent of the longest transcripts of the h...  pc_1_8
#    11043                                       inflammation  pc_1_8
#    24400  RPE reprogramming, dataset: 1642a68a2db75afc3f...  pc_2_9
#    12414                       plts-Sil-tg only, common 1+4  pc_1_9
#    24367                                       Pi Gene list  pc_2_9
#    22158                                             damage  pc_2_7
#    20095                                  ALX1 target genes  pc_2_6
#    24633                                          clay dawn  pc_2_9
#    24879                                         modulatity  pc_2_9
#    24296                    ModularityInvasive and Stage2Ac  pc_2_9
#    19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
#    22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8
#    23040           Methylated-Diferentially Expressed Genes  pc_2_8
#    23942                                   CHDI mouse liver  pc_2_9
#
#           adjusted_score
#    11063    29196.217453
#    22331     7185.850801
#    9811      6120.227832
#    21079     6021.470935
#    12315     4750.949892
#    23909     3273.073021
#    23195     2880.320981
#    23154     2766.612886
#    24158     2599.979875
#    11331     2430.301930
#    24647     2100.832960
#    8350      2040.534735
#    11927     1927.710242
#    8559      1913.093011
#    6487      1728.067087
#    23631     1706.365600
#    24401     1693.005612
#    12295     1639.581538
#    24209     1576.678269
#    11955     1456.985613
#    24372     1444.809113
#    23583     1423.053842
#    22828     1385.840574
#    24619     1265.565727
#    11703     1240.747071
#    24677     1223.444666
#    24501     1112.628728
#    10794     1109.892266
#    12106     1095.598866
#    22588     1093.411097
#    24132     1089.956636
#    24544     1064.114781
#    11051     1054.297727
#    22660     1046.979203
#    21452     1044.141042
#    11918     1008.013892
#    10020     1006.771621
#    11043      973.237161
#    24400      940.791718
#    12414      931.782116
#    24367      931.482218
#    22158      925.769618
#    20095      872.886902
#    24633      859.305326
#    24879      854.306704
#    24296      846.405380
#    19827      836.160958
#    22864      823.573727
#    23040      803.040771
#    23942      801.500779  }}}

# %%
top_fifty_byscore_df
# Out:
#                                                  pathway     bin  \
# 11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
# 22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
# 9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
# 21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
# 12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
# 23909                            Basal 2 control Vs COPD  pc_2_9
# 23195                                     SLE risk genes  pc_2_8
# 23154  Rat proximal tubule TF network identified by wTO.  pc_2_8
# 24158         HMGB1-interacted proteins pathway analysis  pc_2_9
# 11331                                  ALX1 target genes  pc_1_9
# 24647      common genes from iCLIP and RNA-seq data sets  pc_2_9
# 8350                                       child obesity  pc_1_6
# 11927                                     SLE risk genes  pc_1_9
# 8559   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_6
# 6487   Depending on gender, these genes can have vary...  pc_1_5
# 23631                           mouse aging anti gomperz  pc_2_8
# 24401  RPE reprogramming, dataset: 2185b5e32d0c3edf0c...  pc_2_9
# 12295                                       inflammation  pc_1_9
# 24209       Identified by the KroganLab in 2020 (nature)  pc_2_9
# 11955                 Sofosbuvir-Down Sars-Cov-2-S7-1-Up  pc_1_9
# 24372                           Prlr +/- from beta cells  pc_2_9
# 23583  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_8
# 22828                                        GE-K9-4-bed  pc_2_8
# 24619                        capan1 downregulated p<0.05  pc_2_9
# 11703                                            KHAZAYI  pc_1_9
# 24677                                    diabetes type 1  pc_2_9
# 24501  TNBC vs Normal Differential Gene Expression An...  pc_2_9
# 10794                                          XP8GY-12H  pc_1_8
# 12106                                      child obesity  pc_1_9
# 22588                                      AD candidates  pc_2_8
# 24132                                       Genes of IMF  pc_2_9
# 24544         Up in vitamin C in endothelial cells human  pc_2_9
# 11051                                   kc exo mass spec  pc_1_8
# 22660  Biological insights from 108 schizophrenia-ass...  pc_2_8
# 21452                                        CancerGenes  pc_2_7
# 11918                                       SCD survival  pc_1_9
# 10020  10 percent of the longest transcripts of the h...  pc_1_8
# 11043                                       inflammation  pc_1_8
# 24400  RPE reprogramming, dataset: 1642a68a2db75afc3f...  pc_2_9
# 12414                       plts-Sil-tg only, common 1+4  pc_1_9
# 24367                                       Pi Gene list  pc_2_9
# 22158                                             damage  pc_2_7
# 20095                                  ALX1 target genes  pc_2_6
# 24633                                          clay dawn  pc_2_9
# 24879                                         modulatity  pc_2_9
# 24296                    ModularityInvasive and Stage2Ac  pc_2_9
# 19827  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_5
# 22864  Genes associated with osteonecrosis in ALL chi...  pc_2_8
# 23040           Methylated-Diferentially Expressed Genes  pc_2_8
# 23942                                   CHDI mouse liver  pc_2_9
#
#        adjusted_score
# 11063    29196.217453
# 22331     7185.850801
# 9811      6120.227832
# 21079     6021.470935
# 12315     4750.949892
# 23909     3273.073021
# 23195     2880.320981
# 23154     2766.612886
# 24158     2599.979875
# 11331     2430.301930
# 24647     2100.832960
# 8350      2040.534735
# 11927     1927.710242
# 8559      1913.093011
# 6487      1728.067087
# 23631     1706.365600
# 24401     1693.005612
# 12295     1639.581538
# 24209     1576.678269
# 11955     1456.985613
# 24372     1444.809113
# 23583     1423.053842
# 22828     1385.840574
# 24619     1265.565727
# 11703     1240.747071
# 24677     1223.444666
# 24501     1112.628728
# 10794     1109.892266
# 12106     1095.598866
# 22588     1093.411097
# 24132     1089.956636
# 24544     1064.114781
# 11051     1054.297727
# 22660     1046.979203
# 21452     1044.141042
# 11918     1008.013892
# 10020     1006.771621
# 11043      973.237161
# 24400      940.791718
# 12414      931.782116
# 24367      931.482218
# 22158      925.769618
# 20095      872.886902
# 24633      859.305326
# 24879      854.306704
# 24296      846.405380
# 19827      836.160958
# 22864      823.573727
# 23040      803.040771
# 23942      801.500779

# %%
top_five_perclust_df
# Out:
#                                                  pathway     bin  \
# 11063  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_8
# 22331  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_7
# 9811   lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_7
# 21079  lead SNPs from Neale v2 analysis of UKBB data,...  pc_2_6
# 12315  lead SNPs from Neale v2 analysis of UKBB data,...  pc_1_9
# ...                                                  ...     ...
# 6053                                       laminB1 over3  pc_1_4
# 382                               Hashimoto, 1.2 fold up  pc_1_0
# 381                                    Harvard home work  pc_1_0
# 380        HYDROXYCHLOROQUINE-UP SARS-COV-2-UP-Cluster-1  pc_1_0
# 379             HYDROXYCHLOROQUINE-UP SARS-COV-2-S7-1-UP  pc_1_0
#
#        adjusted_score
# 11063    29196.217453
# 22331     7185.850801
# 9811      6120.227832
# 21079     6021.470935
# 12315     4750.949892
# ...               ...
# 6053         0.000000
# 382          0.000000
# 381          0.000000
# 380          0.000000
# 379          0.000000
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Plotting functions

# %% [markdown]
# ### Heatmap plots for comparing cluster pathway association.

# %%
def chart_cluster_pathway(data_array, x_lab, y_lab, z_lab, title_str, text_precision = ".0f"):
    # Convert this grid to columnar data expected by Altair
    title = alt.TitleParams(title_str, anchor='middle')
    chart = alt.Chart(data_array, title = title).mark_rect().encode(
        alt.X(x_lab+":O").title(x_lab),
        alt.Y(y_lab+":O").title(y_lab),
        alt.Color(z_lab+":Q").title(z_lab)
        ).properties(
            width=400,
            height=400
        )
    text = chart.mark_text(baseline='middle').encode(
    alt.Text(z_lab+':Q', format = text_precision),
    color=alt.value('black')
)
    return(chart+text)

# %% [markdown]
# ### Plot the top five for each cluster and the top fifty pathways overall. For Odds-ratio and combined-score

# %%
x_lab = "cluster_number"
y_lab = "pathway"
tex_list = []
for lab in cluster_method_labels:
    lab = lab.replace("_"," ").title().replace(" ","")
    title_str_per = '{} pathways per cluster for cluster method {}'
    title_str_ove = '{} pathways over all clusters for cluster method {}'
    save_str = path_plots+ "/{}ClusterPaths{}{}.png"
    # OR plots 
    # - Top 5 per clust
    top_five_or_title = title_str_per.format(top_five_lab,lab)
    df = path_tops_dict[lab][OR_lab][top_five_lab]
    chart = chart_cluster_pathway(df,x_lab, y_lab, OR_lab, top_five_or_title)
    fname = save_str.format(top_five_lab, OR_lab,lab)
    chart.save(fname)
    tex_list +=[pathway_figure_tex(lab,  fname= fname, score = "Odds Ratio", filter = "top five per cluster")]
    # - Top 50
    top_fifty_or_title = title_str_ove.format(top_fifty_lab, lab)
    chart = chart_cluster_pathway(path_tops_dict[lab][OR_lab][top_fifty_lab],x_lab, y_lab, OR_lab, top_fifty_or_title)
    fname = save_str.format(top_fifty_lab, OR_lab, lab)
    chart.save(fname)
    tex_list +=[pathway_figure_tex(lab, fname= fname, score = "Odds Ratio", filter = "top fifty overall")]
    # Combined score
    # - Top 5 per clust
    top_five_score_title = title_str_per.format(top_five_lab, lab)
    chart = chart_cluster_pathway(path_tops_dict[lab][score_lab][top_five_lab],x_lab, y_lab, score_lab, top_five_score_title)
    fname = save_str.format(top_five_lab, score_lab,lab)
    chart.save(fname)
    tex_list +=[pathway_figure_tex(lab,  fname= fname, score = "Combined Score", filter = "top five per cluster")]
    # - Top 50
    top_fifty_score_title = title_str_ove.format(top_fifty_lab, lab)
    chart = chart_cluster_pathway(path_tops_dict[lab][score_lab][top_fifty_lab],x_lab, y_lab, score_lab, top_fifty_score_title)
    fname= save_str.format(top_fifty_lab, score_lab,lab)
    chart.save(fname)
    tex_list +=[pathway_figure_tex(lab, fname= fname, score = "Combined Score", filter = "top fifty overall")]
chart
# Out:
# alt.LayerChart(...)

# %%
x_lab = "bin"
y_lab = "pathway"
for lab in path_pca_tops_dict.keys():
    title_str = '{} pathways per PCA bin for transform {}'
    save_str = path_plots+ "/{}_pca_paths_{}_{}.png"
    # OR plots 
    # - Top 5 per clust
    top_five_or_title = title_str.format(top_five_lab,lab)
    df = path_pca_tops_dict[lab][OR_lab][top_five_lab]
    chart = chart_cluster_pathway(df,x_lab, y_lab, OR_lab, top_five_or_title)
    fname = save_str.format(top_five_lab, OR_lab, lab)
    chart.save(fname)
    # # - Top 50
    top_fifty_or_title = title_str.format(top_fifty_lab, lab)
    chart = chart_cluster_pathway(path_pca_tops_dict[lab][OR_lab][top_fifty_lab],x_lab, y_lab, OR_lab, top_fifty_or_title)
    fname = save_str.format(top_fifty_lab, OR_lab, lab)
    chart.save(fname)
    # Combined score
    # - Top 5 per clust
    top_five_score_title = title_str.format(top_five_lab, lab)
    chart = chart_cluster_pathway(path_pca_tops_dict[lab][score_lab][top_five_lab],x_lab, y_lab, score_lab, top_five_score_title)
    fname = save_str.format(top_five_lab, score_lab,lab)
    chart.save(fname)
    # - Top 50
    top_fifty_score_title = title_str.format(top_fifty_lab, lab)
    chart = chart_cluster_pathway(path_pca_tops_dict[lab][score_lab][top_fifty_lab],x_lab, y_lab, score_lab, top_fifty_score_title)
    fname = save_str.format(top_fifty_lab, score_lab,lab)
    chart.save(fname)
    # Adjusted Combined score
    # - Top 5 per clust
    top_five_score_title = title_str.format(top_five_lab, lab)
    chart = chart_cluster_pathway(path_pca_tops_dict[lab][adj_score_lab][top_five_lab],x_lab, y_lab, adj_score_lab, top_five_score_title)
    fname = save_str.format(top_five_lab, adj_score_lab,lab)
    chart.save(fname)
    # - Top 50
    top_fifty_score_title = title_str.format(top_fifty_lab, lab)
    chart = chart_cluster_pathway(path_pca_tops_dict[lab][adj_score_lab][top_fifty_lab],x_lab, y_lab, adj_score_lab, top_fifty_score_title)
    fname = save_str.format(top_fifty_lab, adj_score_lab,lab)
    chart.save(fname)
chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Comparing the cluster methods
# In an ideal scenario our clustering method would:
# * identify pathways which have not been split accross other clusters.
# * separate the pathways from each other so they can be identified.
#
# In addition to this we also want to consider whether the pathways identified have significant enrichment and if so utilise this to inform further treatment investigation.

# %% [markdown]
# ## How well has each cluster methods performed on not splitting clusters up?

# %%
def ssd(A,B):
  dif = A.ravel() - B.ravel()
  return abs(dif).sum()/(len(A.ravel()))
def uniqueness(df, axis = 0, score_lab = "combined_score"):
    df_wide = df.pivot_table(index='pathway', columns='cluster_number', values=score_lab)
    if df_wide.shape[1]==1 and axis ==1: return("NaN")
    mat = np.nan_to_num(df_wide.to_numpy())
    if axis == 1:
      mat = mat.T
    mat_norm = (mat - mat.min(0))/ mat.ptp(0)
    max_mat = np.zeros(mat_norm.shape)
    max_mat[np.argmax(mat_norm, axis = 0)] = 1
    score = ssd(max_mat, mat_norm)
    return(score)
def clust_path_score(df, score_lab = score_lab):
  path_contain_score = uniqueness(df, axis = 0, score_lab=score_lab)
  path_separate_score = uniqueness(df, axis = 1, score_lab=score_lab)
  out_dict = {"PathContaining": path_contain_score,
               "PathSeparating": path_separate_score}
  return(out_dict)

# %%
def rescale_col (df, col_lab):
  num_col = pd.to_numeric(df[col_lab], errors='coerce')
  not_nan_rows = num_col.notnull()
  num_col[not_nan_rows] = (num_col[not_nan_rows] - num_col[not_nan_rows].min())/ (num_col[not_nan_rows].max()- num_col[not_nan_rows].min())
  return(num_col[not_nan_rows])

# %%
clust_method_scores_df.PathContaining
# Out:
# 8     0.000000
# 17    0.168617
# 16    0.168617
# 18    0.168617
# 19    0.192361
# 14    0.081227
# 13    0.263454
# 11    0.189508
# 7     0.202920
# 12    0.106824
# 6     0.189003
# 5     0.192186
# 3     0.211330
# 2     0.249573
# 0     0.249573
# 4     0.179412
# 1     0.255066
# 15    1.000000
# 9     0.081976
# 10    0.081976
# Name: PathContaining, dtype: float64

# %%
clust_method_scores = []
for lab in cluster_method_labels:
    clust_path_dict = clust_path_score(path_clust_OR_dict[lab], score_lab=OR_lab)
    clust_path_dict["ClusterMethod"]=  lab
    clust_method_scores.append(clust_path_dict)
# Rescale the cluster scores.
cont_weight = 0.90
sep_weight = 0.1
clust_method_scores_df = pd.DataFrame(clust_method_scores)
clust_method_scores_df.PathContaining = rescale_col(clust_method_scores_df, "PathContaining")
clust_method_scores_df.PathSeparating = rescale_col(clust_method_scores_df, "PathSeparating")
clust_method_scores_df["OverallPathwayIdentifying"] = cont_weight * clust_method_scores_df.PathContaining + sep_weight * clust_method_scores_df.PathSeparating
clust_method_scores_df.sort_values(by="OverallPathwayIdentifying", ascending=True, na_position="last")
# Out:
#     PathContaining  PathSeparating                      ClusterMethod  \
# 8         0.000000        0.000000                 DBScanZeroProposed
# 14        0.081391        0.452547                     GMMOneProposed
# 17        0.168957        0.000000                   BirchTwoProposed
# 16        0.168957        0.000000                   BirchOneProposed
# 18        0.168957        0.000000      KmeansCosineTwoMinAICProposed
# 12        0.107039        0.602011          KmedoidsCosineSixProposed
# 19        0.192749        0.159654  KmedoidsCosineThreeMinAICProposed
# 6         0.189384        0.250035      KmedoidsEuclideanProposedFour
# 5         0.192573        0.230169         KmeansElkanStdFourProposed
# 3         0.192573        0.230169         KmeansLloydStdFourProposed
# 4         0.179774        0.468810          KmeansLloydStdSixProposed
# 11        0.189890        0.513248   KmeansCosineMinibatchSixProposed
# 7         0.203330        0.457834            KmeansCosineSixProposed
# 13        0.263985        0.115324                    GMMZeroProposed
# 2         0.250076        0.286592          KmeansElkanStdFourDarrous
# 0         0.250076        0.286592          KmeansLloydStdFourDarrous
# 1         0.255581        0.476932           KmeansLloydStdSixDarrous
# 15        1.000000        1.000000                  BirchZeroProposed
# 9         0.082141             NaN                  DBScanOneProposed
# 10        0.082141             NaN                  DBScanTwoProposed
#
#     OverallPathwayIdentifying
# 8                    0.000000
# 14                   0.118507
# 17                   0.152061
# 16                   0.152061
# 18                   0.152061
# 12                   0.156536
# 19                   0.189440
# 6                    0.195449
# 5                    0.196333
# 3                    0.196333
# 4                    0.208678
# 11                   0.222226
# 7                    0.228780
# 13                   0.249119
# 2                    0.253728
# 0                    0.253728
# 1                    0.277716
# 15                   1.000000
# 9                         NaN
# 10                        NaN

# %% [markdown]
# ## Account for overfitting
# Divide the cluster pathway score by the `AIC`. This will adjust for methods which are overfitting clusters.

# %%
clust_method_scores_df["aic"] = [clustering_info.loc[lab, "aic"] for lab in clust_method_scores_df.ClusterMethod]
clust_method_scores_df["AdjustedPathContaining"] = clust_method_scores_df.PathContaining*clust_method_scores_df.aic
clust_method_scores_df["AdjustedPathSeparating"] = clust_method_scores_df.PathSeparating*clust_method_scores_df.aic
clust_method_scores_df.AdjustedPathContaining = rescale_col(clust_method_scores_df, "AdjustedPathContaining")
clust_method_scores_df.AdjustedPathSeparating = rescale_col(clust_method_scores_df, "AdjustedPathSeparating")
clust_method_scores_df["AdjustedOverall"] = cont_weight*clust_method_scores_df.AdjustedPathContaining + sep_weight*clust_method_scores_df.AdjustedPathSeparating

clust_method_scores_df.sort_values(by="AdjustedOverall", ascending=True, na_position="last",inplace=True)
clust_method_scores_df.to_csv(tex_dir+"/ClusterPathwayComparions.csv", 
                              float_format='%.3f')
clust_method_scores_df
# Out:
#     PathContaining  PathSeparating                      ClusterMethod  \
# 8         0.000000        0.000000                 DBScanZeroProposed
# 17        0.168957        0.000000                   BirchTwoProposed
# 16        0.168957        0.000000                   BirchOneProposed
# 18        0.168957        0.000000      KmeansCosineTwoMinAICProposed
# 19        0.192749        0.159654  KmedoidsCosineThreeMinAICProposed
# 14        0.081391        0.452547                     GMMOneProposed
# 13        0.263985        0.115324                    GMMZeroProposed
# 11        0.189890        0.513248   KmeansCosineMinibatchSixProposed
# 7         0.203330        0.457834            KmeansCosineSixProposed
# 12        0.107039        0.602011          KmedoidsCosineSixProposed
# 6         0.189384        0.250035      KmedoidsEuclideanProposedFour
# 5         0.192573        0.230169         KmeansElkanStdFourProposed
# 3         0.192573        0.230169         KmeansLloydStdFourProposed
# 2         0.250076        0.286592          KmeansElkanStdFourDarrous
# 0         0.250076        0.286592          KmeansLloydStdFourDarrous
# 4         0.179774        0.468810          KmeansLloydStdSixProposed
# 1         0.255581        0.476932           KmeansLloydStdSixDarrous
# 15        1.000000        1.000000                  BirchZeroProposed
# 9         0.082141             NaN                  DBScanOneProposed
# 10        0.082141             NaN                  DBScanTwoProposed
#
#     OverallPathwayIdentifying            aic  AdjustedPathContaining  \
# 8                    0.000000    5698.360008                0.000000
# 17                   0.152061    1959.091867                0.001250
# 16                   0.152061    1959.091867                0.001250
# 18                   0.152061    2953.690816                0.001885
# 19                   0.189440    6053.822311                0.004408
# 14                   0.118507    9840.977985                0.003026
# 13                   0.249119    5537.238223                0.005522
# 11                   0.222226    6597.522864                0.004733
# 7                    0.228780    7170.450067                0.005508
# 12                   0.156536   10553.675863                0.004268
# 6                    0.195449   14910.143710                0.010667
# 5                    0.196333   47432.884363                0.034507
# 3                    0.196333   47432.884363                0.034507
# 2                    0.253728   40169.834883                0.037949
# 0                    0.253728   40169.834883                0.037949
# 4                    0.208678   49809.327363                0.033828
# 1                    0.277716   40016.885845                0.038637
# 15                   1.000000  264708.032968                1.000000
# 9                         NaN    3973.980002                0.001233
# 10                        NaN    3973.980002                0.001233
#
#     AdjustedPathSeparating  AdjustedOverall
# 8                 0.000000         0.000000
# 17                0.000000         0.001125
# 16                0.000000         0.001125
# 18                0.000000         0.001697
# 19                0.003651         0.004332
# 14                0.016824         0.004406
# 13                0.002412         0.005211
# 11                0.012792         0.005539
# 7                 0.012402         0.006197
# 12                0.024002         0.006241
# 6                 0.014084         0.011009
# 5                 0.041244         0.035181
# 3                 0.041244         0.035181
# 2                 0.043491         0.038504
# 0                 0.043491         0.038504
# 4                 0.088215         0.039266
# 1                 0.072100         0.041983
# 15                1.000000         1.000000
# 9                      NaN              NaN
# 10                     NaN              NaN

# %%
with open(tex_dir+"/cluster_pathway_figures_text.tex", "w") as text_file:
    for tex_item in tex_list:
        text_file.write(tex_item)
